# %%
import torch

print(torch.cuda.is_available())

if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
import pandas as pd

df = pd.read_csv("../data/kaggle_raw/customer_support_tickets.csv")

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1720/15135114.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("../data/kaggle_raw/customer_support_tickets.csv")
#       4
#       5 print("Shape:", df.shape)
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/kaggle_raw/customer_support_tickets.csv'

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

path = "/content/drive/MyDrive/SupportOpsAI/data/kaggle_raw/customer_support_tickets.csv"

print(os.path.exists(path))
# Out:
# True

# %%
import pandas as pd

df = pd.read_csv(path)

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

display(df.head())
# Out:
# Shape: (8469, 17)
#
# Columns:
# ['Ticket ID', 'Customer Name', 'Customer Email', 'Customer Age', 'Customer Gender', 'Product Purchased', 'Date of Purchase', 'Ticket Type', 'Ticket Subject', 'Ticket Description', 'Ticket Status', 'Resolution', 'Ticket Priority', 'Ticket Channel', 'First Response Time', 'Time to Resolution', 'Customer Satisfaction Rating']
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# 1  Peripheral compatibility
# 2           Network problem
# 3            Account access
# 4                 Data loss
#
#                                   Ticket Description  \
# 0  I'm having an issue with the {product_purchase...
# 1  I'm having an issue with the {product_purchase...
# 2  I'm facing a problem with my {product_purchase...
# 3  I'm having an issue with the {product_purchase...
# 4  I'm having an issue with the {product_purchase...
#
#                Ticket Status                                     Resolution  \
# 0  Pending Customer Response                                            NaN
# 1  Pending Customer Response                                            NaN
# 2                     Closed   Case maybe show recently my computer follow.
# 3                     Closed  Try capital clearly never color toward story.
# 4                     Closed                    West decision evidence bit.
#
#   Ticket Priority Ticket Channel  First Response Time   Time to Resolution  \
# 0        Critical   Social media  2023-06-01 12:15:36                  NaN
# 1        Critical           Chat  2023-06-01 16:45:38                  NaN
# 2             Low   Social media  2023-06-01 11:14:38  2023-06-01 18:05:38
# 3             Low   Social media  2023-06-01 07:29:40  2023-06-01 01:57:40
# 4             Low          Email  2023-06-01 00:12:42  2023-06-01 19:53:42
#
#    Customer Satisfaction Rating
# 0                           NaN
# 1                           NaN
# 2                           3.0
# 3                           3.0
# 4                           1.0

# %%
print("Ticket Types:")
print(df["Ticket Type"].value_counts())

print("\nPriorities:")
print(df["Ticket Priority"].value_counts())

print("\nStatuses:")
print(df["Ticket Status"].value_counts())
# Out:
# Ticket Types:
# Ticket Type
# Refund request          1752
# Technical issue         1747
# Cancellation request    1695
# Product inquiry         1641
# Billing inquiry         1634
# Name: count, dtype: int64
#
# Priorities:
# Ticket Priority
# Medium      2192
# Critical    2129
# High        2085
# Low         2063
# Name: count, dtype: int64
#
# Statuses:
# Ticket Status
# Pending Customer Response    2881
# Open                         2819
# Closed                       2769
# Name: count, dtype: int64

# %%
print(
    df[[
        "Ticket Type",
        "Ticket Subject",
        "Ticket Description",
        "Ticket Priority",
        "Resolution"
    ]].head(10)
)
# Out:
#             Ticket Type            Ticket Subject  \
# 0       Technical issue             Product setup
# 1       Technical issue  Peripheral compatibility
# 2       Technical issue           Network problem
# 3       Billing inquiry            Account access
# 4       Billing inquiry                 Data loss
# 5  Cancellation request             Payment issue
# 6       Product inquiry            Refund request
# 7        Refund request              Battery life
# 8       Technical issue      Installation support
# 9        Refund request             Payment issue
#
#                                   Ticket Description Ticket Priority  \
# 0  I'm having an issue with the {product_purchase...        Critical
# 1  I'm having an issue with the {product_purchase...        Critical
# 2  I'm facing a problem with my {product_purchase...             Low
# 3  I'm having an issue with the {product_purchase...             Low
# 4  I'm having an issue with the {product_purchase...             Low
# 5  I'm facing a problem with my {product_purchase...             Low
# 6  I'm unable to access my {product_purchased} ac...        Critical
# 7  I'm having an issue with the {product_purchase...        Critical
# 8  I'm having an issue with the {product_purchase...             Low
# 9  My {product_purchased} is making strange noise...        Critical
#
#                                       Resolution
# 0                                            NaN
# 1                                            NaN
# 2   Case maybe show recently my computer follow.
# 3  Try capital clearly never color toward story.
# 4                    West decision evidence bit.
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN

# %%
for i, row in df.head(10).iterrows():
    print("=" * 80)
    print("TYPE:", row["Ticket Type"])
    print("SUBJECT:", row["Ticket Subject"])
    print("PRIORITY:", row["Ticket Priority"])
    print("DESCRIPTION:", row["Ticket Description"])
# Out:
# ================================================================================
# TYPE: Technical issue
# SUBJECT: Product setup
# PRIORITY: Critical
# DESCRIPTION: I'm having an issue with the {product_purchased}. Please assist.
#
# Your billing zip code is: 71701.
#
# We appreciate that you have requested a website address.
#
# Please double check your email address. I've tried troubleshooting steps mentioned in the user manual, but the issue persists.
# ================================================================================
# TYPE: Technical issue
# SUBJECT: Peripheral compatibility
# PRIORITY: Critical
# DESCRIPTION: I'm having an issue with the {product_purchased}. Please assist.
#
# If you need to change an existing product.
#
# I'm having an issue with the {product_purchased}. Please assist.
#
# If The issue I'm facing is intermittent. Sometimes it works fine, but other times it acts up unexpectedly.
# ================================================================================
# TYPE: Technical issue
# SUBJECT: Network problem
# PRIORITY: Low
# DESCRIPTION: I'm facing a problem with my {product_purchased}. The {product_purchased} is not turning on. It was working fine until yesterday, but now it doesn't respond.
#
# 1.8.3 I really I'm using the original charger that came with my {product_purchased}, but it's not charging properly.
# ================================================================================
# TYPE: Billing inquiry
# SUBJECT: Account access
# PRIORITY: Low
# DESCRIPTION: I'm having an issue with the {product_purchased}. Please assist.
#
# If you have a problem you're interested in and I'd love to see this happen, please check out the Feedback. I've already contacted customer support multiple times, but the issue remains unresolved.
# ================================================================================
# TYPE: Billing inquiry
# SUBJECT: Data loss
# PRIORITY: Low
# DESCRIPTION: I'm having an issue with the {product_purchased}. Please assist.
#
#
# Note: The seller is not responsible for any damages arising out of the delivery of the battleground game. Please have the game in good condition and shipped to you I've noticed a sudden decrease in battery life on my {product_purchased}. It used to last much longer.
# ================================================================================
# TYPE: Cancellation request
# SUBJECT: Payment issue
# PRIORITY: Low
# DESCRIPTION: I'm facing a problem with my {product_purchased}. The {product_purchased} is not turning on. It was working fine until yesterday, but now it doesn't respond. To remove the new {product_purch I've checked for any available software updates for my {product_purchased}, but there are none.
# ================================================================================
# TYPE: Product inquiry
# SUBJECT: Refund request
# PRIORITY: Critical
# DESCRIPTION: I'm unable to access my {product_purchased} account. It keeps displaying an 'Invalid Credentials' error, even though I'm using the correct login information. How can I regain access to my account?
#
# Solution 1 I'm unable to find the option to perform the desired action in the {product_purchased}. Could you please guide me through the steps?
# ================================================================================
# TYPE: Refund request
# SUBJECT: Battery life
# PRIORITY: Critical
# DESCRIPTION: I'm having an issue with the {product_purchased}. Please assist. (Thanks) I will contact all my suppliers and confirm.
#
# Please try and find out whether their inventory is currently stocked, or any other reason. I am I've performed a factory reset on my {product_purchased}, hoping it would resolve the problem, but it didn't help.
# ================================================================================
# TYPE: Technical issue
# SUBJECT: Installation support
# PRIORITY: Low
# DESCRIPTION: I'm having an issue with the {product_purchased}. Please assist. Thank you.
#
# {product_purchased} is not the exact type you might prefer, they use the exact same method for different uses. Please help I've recently updated the firmware of my {product_purchased}, and the issue started happening afterward. Could it be related to the update?
# ================================================================================
# TYPE: Refund request
# SUBJECT: Payment issue
# PRIORITY: Critical
# DESCRIPTION: My {product_purchased} is making strange noises and not functioning properly. I suspect there might be a hardware issue. Can you please help me with this?
#
# } If we can, please send a "request" to dav The issue I'm facing is intermittent. Sometimes it works fine, but other times it acts up unexpectedly.

# %%
print(
    df["Ticket Description"]
    .str.contains(r"\{.*?\}", regex=True, na=False)
    .sum(),
    "tickets contain placeholders"
)
# Out:
# 8469 tickets contain placeholders

# %%
print(
    df["Resolution"].notna().sum(),
    "tickets have a resolution"
)
# Out:
# 2769 tickets have a resolution

# %%
ls
# Out:
# drive/  sample_data/

# %%
ls
# Out:
# bin@                kaggle/                   proc/                sys/
# bin.usr-is-merged/  lib@                      python-apt/          tmp/
# boot/               lib64@                    python-apt.tar.xz*   tools/
# content/            lib.usr-is-merged/        root/                usr/
# datalab/            media/                    run/                 var/
# dev/                mnt/                      sbin@
# etc/                NGC-DL-CONTAINER-LICENSE  sbin.usr-is-merged/
# home/               opt/                      srv/

# %%
# !ls /content/drive/MyDrive/SupportOpsAI
# Out:
# data

# %%
# !ls /content/drive/MyDrive/SupportOpsAI/data/kaggle_raw
# Out:
# customer_support_tickets.csv

# %%
import json
import random

text_col = "Ticket Description"

texts = df[text_col].dropna().astype(str).tolist()

random.seed(42)

sample = random.sample(
    texts,
    min(70, len(texts))
)

seed_path = "/content/drive/MyDrive/SupportOpsAI/data/seed_texts.jsonl"

with open(seed_path, "w", encoding="utf-8") as f:
    for t in sample:
        f.write(
            json.dumps(
                {"raw_text": t.strip()},
                ensure_ascii=False
            ) + "\n"
        )

print(f"Extracted {len(sample)} ticket texts")
print(f"Saved to: {seed_path}")
# Out:
# Extracted 70 ticket texts
# Saved to: /content/drive/MyDrive/SupportOpsAI/data/seed_texts.jsonl

# %%
for i, ticket in enumerate(sample[:10], 1):
    print(f"\n--- Ticket {i} ---")
    print(ticket)
# Out:
# --- Ticket 1 ---
# I'm having an issue with the {product_purchased}. Please assist. Thanks.
#
# If you need a product for free, please use our support page. Please contact support@vendorsparklabs.com. I've performed a factory reset on my {product_purchased}, hoping it would resolve the problem, but it didn't help.
#
# --- Ticket 2 ---
# My {product_purchased} crashed, and I lost all the data stored on it. Is there any way to recover the lost data? If your data is not safe from other users, I'd like to know how you managed to recover I've noticed that the issue occurs consistently when I use a specific feature or application on my {product_purchased}.
#
# --- Ticket 3 ---
# I've noticed a software bug in the {product_purchased} app. It's causing data loss and unexpected errors. How can I resolve this issue?
#
# Install the Software
#
# Open your Mac Settings > Applications > Privacy > Software I'm concerned about the security of my {product_purchased} and would like to ensure that my data is safe.
#
# --- Ticket 4 ---
# I'm facing a problem with my {product_purchased}. The {product_purchased} is not turning on. It was working fine until yesterday, but now it doesn't respond.
#
# This is a pain in the ass I've followed the troubleshooting steps mentioned in the user manual, but the issue persists.
#
# --- Ticket 5 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# "
#
# "I feel like you're very responsible to me for knowing this product. I've been going through this since January 10th. Please assist I've tried different settings and configurations on my {product_purchased}, but the issue persists.
#
# --- Ticket 6 ---
# The {product_purchased} is unable to establish a stable internet connection. It keeps disconnecting intermittently. How can I troubleshoot this network problem? *
#
# Note that the same thing can happen to your web apps when you I'm unable to find the option to perform the desired action in the {product_purchased}. Could you please guide me through the steps?
#
# --- Ticket 7 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# Your name?
#
# If you are registering for the product, your product is now being purchased. The only difference, of course, is that your customer I've tried troubleshooting steps mentioned in the user manual, but the issue persists.
#
# --- Ticket 8 ---
# I'm having an issue with the {product_purchased}. Please assist. You can call or write us at 1-888-873-1060 to request information about ordering for a new product or have it removed.
#
# We I've recently updated the firmware of my {product_purchased}, and the issue started happening afterward. Could it be related to the update?
#
# --- Ticket 9 ---
# I'm having an issue with the {product_purchased}. Please assist. {{product_purchased}}
#
# {product_refresh_to}} {{review_created}}
#
# {review_total_refresh}} I've performed a factory reset on my {product_purchased}, hoping it would resolve the problem, but it didn't help.
#
# --- Ticket 10 ---
# I'm having an issue with the {product_purchased}. Please assist. If you have any further feedback, please drop me an email at xanj@comcast.net.
#
# [This post has been updated.] I've recently updated the firmware of my {product_purchased}, and the issue started happening afterward. Could it be related to the update?

# %%
for i, ticket in enumerate(sample[10:], 11):
    print(f"\n--- Ticket {i} ---")
    print(ticket)
# Out:
# --- Ticket 11 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# For a list of specific devices, please contact us.
#
#
# If your product is not listed in the list on this page, please see our Help Center I've performed a factory reset on my {product_purchased}, hoping it would resolve the problem, but it didn't help.
#
# --- Ticket 12 ---
# I'm unable to access my {product_purchased} account. It keeps displaying an 'Invalid Credentials' error, even though I'm using the correct login information. How can I regain access to my account?
#
# When the I've reviewed the troubleshooting steps on the official support website, but they didn't resolve the problem.
#
# --- Ticket 13 ---
# I'm having an issue with the {product_purchased}. Please assist. $55.00
#
# 1. Add # of items to cart
#
# Add $55 (plus taxes) to cart.
#
# Add Item to Cart I've checked the device settings and made sure that everything is configured correctly.
#
# --- Ticket 14 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
#
# Dangerous and difficult to remove or discard:
#
#
# Lethally-based products do NOT have to be discarded. It is important to avoid putting I've checked for software updates, and my {product_purchased} is already running the latest version.
#
# --- Ticket 15 ---
# I'm having an issue with the {product_purchased}. Please assist. I'll fix it as quickly as I can! Thank you."
#
# It's not just the text that changes these numbers that makes the results appear to be wrong I've recently updated the firmware of my {product_purchased}, and the issue started happening afterward. Could it be related to the update?
#
# --- Ticket 16 ---
# I'm unable to access my {product_purchased} account. It keeps displaying an 'Invalid Credentials' error, even though I'm using the correct login information. How can I regain access to my account? The account is temporarily I've tried using different cables, adapters, or peripherals with my {product_purchased}, but the issue persists.
#
# --- Ticket 17 ---
# I've forgotten my password for my {product_purchased} account, and the password reset option is not working. How can I recover my account? 1. Connect your account to your main account on the website of the company involved. 2 I've checked for software updates, and my {product_purchased} is already running the latest version.
#
# --- Ticket 18 ---
# My {product_purchased} is making strange noises and not functioning properly. I suspect there might be a hardware issue. Can you please help me with this?
#
# Hello dear reader here, this is the question I've wanted to ask I need assistance as soon as possible because it's affecting my work and productivity.
#
# --- Ticket 19 ---
# I'm having an issue with the {product_purchased}. Please assist. Thank You.
#
# My Santa gave me 2 great gifts including a very nice gift card which has a "Buck I Don't Know"-shaped hat I've I've already contacted customer support multiple times, but the issue remains unresolved.
#
# --- Ticket 20 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# This button opens a dialog that displays additional images for this product with the option to zoom in or out.
#
# Please note that some brands ship with custom I've performed a factory reset on my {product_purchased}, hoping it would resolve the problem, but it didn't help.
#
# --- Ticket 21 ---
# I'm having an issue with the {product_purchased}. Please assist. If you have any problems please report an issue now, and we will fix them asap.
#
#
# And please join in by joining my mailing list. I've checked for software updates, and my {product_purchased} is already running the latest version.
#
# --- Ticket 22 ---
# I'm having an issue with the {product_purchased}. Please assist. I've checked the device settings and made sure that everything is configured correctly.
#
# --- Ticket 23 ---
# I'm having an issue with the {product_purchased}. Please assist. I've noticed that the issue occurs consistently when I use a specific feature or application on my {product_purchased}.
#
# --- Ticket 24 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# * This item has an "error description" on its description page in some languages*
#
# C-Y "I'm seeing a product now sold by I've performed a factory reset on my {product_purchased}, hoping it would resolve the problem, but it didn't help.
#
# --- Ticket 25 ---
# I'm having an issue with the {product_purchased}. Please assist. Thanks. It will be fine.
#
# (4) The product is for your personal use only. It does not constitute a license to use the other product. I've tried troubleshooting steps mentioned in the user manual, but the issue persists.
#
# --- Ticket 26 ---
# I've accidentally deleted important data from my {product_purchased}. Is there any way to recover the deleted files? I need them urgently. When I use {name}{name_purchased}, the {products} information, I know I've followed the troubleshooting steps mentioned in the user manual, but the issue persists.
#
# --- Ticket 27 ---
# I'm having an issue with the {product_purchased}. Please assist. A copy of my refund request can usually be found at the link below. Please note that while I'm very happy to assist you with any items that may possibly be I need assistance as soon as possible because it's affecting my work and productivity.
#
# --- Ticket 28 ---
# There seems to be a glitch in the {product_purchased} software. It freezes frequently, making it difficult to use. Can you please provide a solution?
#
# There seems to be a glitch in the {product_purchased I've followed the troubleshooting steps mentioned in the user manual, but the issue persists.
#
# --- Ticket 29 ---
# I've noticed a software bug in the {product_purchased} app. It's causing data loss and unexpected errors. How can I resolve this issue?
#
# Here's what you CAN do:
#
# Search for your project's { I'm worried that the issue might be hardware-related and might require repair or replacement.
#
# --- Ticket 30 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# C# C++
#
# C# 6
#
# <-bool fDebug = "Error reporting to {product_purchased}.
#
# " I've tried different settings and configurations on my {product_purchased}, but the issue persists.
#
# --- Ticket 31 ---
# I'm facing issues logging into my {product_purchased} account. It says my account is locked. What should I do to unlock it?
#
# What is the solutionestead.pl?
#
# This was written by Daniel S. I've followed online tutorials and community forums to troubleshoot the issue, but no luck so far.
#
# --- Ticket 32 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# It seems that there's a bug in this API, so you'll want to enable the 'allow'option to use the URL you want to display when I'm concerned about the security of my {product_purchased} and would like to ensure that my data is safe.
#
# --- Ticket 33 ---
# I'm encountering a software bug in the {product_purchased}. Whenever I try to perform a specific action, the application crashes. Are there any updates or fixes available? What should I do if the code crashes? Why? If I use I need assistance as soon as possible because it's affecting my work and productivity.
#
# --- Ticket 34 ---
# I've noticed a software bug in the {product_purchased} app. It's causing data loss and unexpected errors. How can I resolve this issue?
#
# This issue affects all Android apps, not just yours. If you're on I'm unable to find the option to perform the desired action in the {product_purchased}. Could you please guide me through the steps?
#
# --- Ticket 35 ---
# I'm having an issue with the {product_purchased}. Please assist. I have an issue with the {product_purchased}. Please assist.
#
#
# This item is marked with a check mark. Please enter a valid email address I've already contacted customer support multiple times, but the issue remains unresolved.
#
# --- Ticket 36 ---
# I'm having an issue with the {product_purchased}. Please assist. </td> <td align='center' class='western' display='stdText'></td> <td align='center' class='western' display=' I've noticed a peculiar error message popping up on my {product_purchased} screen. It says '{error_message}'. What does it mean?
#
# --- Ticket 37 ---
# I'm having an issue with the {product_purchased}. Please assist. Thank you if you'll be a quick touch to help you find what you are looking for. I've checked for any available software updates for my {product_purchased}, but there are none.
#
# --- Ticket 38 ---
# My {product_purchased} crashed, and I lost all the data stored on it. Is there any way to recover the lost data?
#
# CMS_T Skydragon_DATA=0x4
#
# CMS_TRUE I need assistance as soon as possible because it's affecting my work and productivity.
#
# --- Ticket 39 ---
# I'm having an issue with the {product_purchased}. Please assist. Please contact me. Thank you for the opportunity to purchase your product.. If I purchase with my own funds, I will ship to you for my product (including any I'm unable to find the option to perform the desired action in the {product_purchased}. Could you please guide me through the steps?
#
# --- Ticket 40 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# It's the only way to receive an address that goes directly to the product you've placed, but even if it's in the same brand, I can I've recently updated the firmware of my {product_purchased}, and the issue started happening afterward. Could it be related to the update?
#
# --- Ticket 41 ---
# I'm having an issue with the {product_purchased}. Please assist. Thank you.
#
# The product_purchased contains all our products and our services are the exclusive property of our supplier, our distributors, and our respective affiliates I'm concerned about the security of my {product_purchased} and would like to ensure that my data is safe.
#
# --- Ticket 42 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# This product is now out of stock and will get replaced.
#
# This product is now out of stock and will get replaced.
#
# This product is I've performed a factory reset on my {product_purchased}, hoping it would resolve the problem, but it didn't help.
#
# --- Ticket 43 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# To make your account secure, please use a secure browser, you may download additional images from this page, or if the client already supports JavaScript enabled, enable I've recently updated the firmware of my {product_purchased}, and the issue started happening afterward. Could it be related to the update?
#
# --- Ticket 44 ---
# I'm having an issue with the {product_purchased}. Please assist. Thank you. I've been told that the product you provided is not a valid e-mail to the recipient. The e-mail can be reviewed by the appropriate I've followed online tutorials and community forums to troubleshoot the issue, but no luck so far.
#
# --- Ticket 45 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
#
# This does not mean you are having any issues, we merely want a speedy fix as soon as possible. I'm unable to find the option to perform the desired action in the {product_purchased}. Could you please guide me through the steps?
#
# --- Ticket 46 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# Your purchase will be valid only if this item is in retail and shipped.
#
# *Product_sizes are for retail only.
#
# Your purchase I've tried troubleshooting steps mentioned in the user manual, but the issue persists.
#
# --- Ticket 47 ---
# I'm having an issue with the {product_purchased}. Please assist. $14 to $14 US
#
# PURCHASE AVAILABLE NOW at www.champagewide.com
#
# Lorem Ipsum I've tried using different cables, adapters, or peripherals with my {product_purchased}, but the issue persists.
#
# --- Ticket 48 ---
# My {product_purchased} crashed, and I lost all the data stored on it. Is there any way to recover the lost data? This will be the end of my account and I won't have any credit cards that need to be I've followed the troubleshooting steps mentioned in the user manual, but the issue persists.
#
# --- Ticket 49 ---
# I've encountered a data loss issue with my {product_purchased}. All the files and documents seem to have disappeared. Can you guide me on how to retrieve them? Thanks!
#
# What was wrong with my data?
#
# " I've recently updated the firmware of my {product_purchased}, and the issue started happening afterward. Could it be related to the update?
#
# --- Ticket 50 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# $29.50 $29.00 $29.00 Quantity
#
# Pressed In 2 oz - $29.50
#
# Pressed In 2 I'm concerned about the security of my {product_purchased} and would like to ensure that my data is safe.
#
# --- Ticket 51 ---
# There seems to be a hardware problem with my {product_purchased}. The screen is flickering, and I'm unable to use it. What should I do?
#
# - If you use this on a non-smart phone like the Galaxy I need assistance as soon as possible because it's affecting my work and productivity.
#
# --- Ticket 52 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# 14 14:25:08 noop, b0j, q1f9:3f, g, 6a:5b5, f I'm concerned about the security of my {product_purchased} and would like to ensure that my data is safe.
#
# --- Ticket 53 ---
# I'm having an issue with the {product_purchased}. Please assist. https://support.apple.com/kb/HT312911
#
# 8 annotation : The author of the book may be notified and the details of any disputes I've checked for software updates, and my {product_purchased} is already running the latest version.
#
# --- Ticket 54 ---
# My {product_purchased} crashed, and I lost all the data stored on it. Is there any way to recover the lost data? I had been in some trouble as a user, and I needed a password to access all of the I've followed the troubleshooting steps mentioned in the user manual, but the issue persists.
#
# --- Ticket 55 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# 1. Please click on the "Product Purchase" link in the Shopping Cart on the right.
#
# 2. If an issue persists after signing up, The issue I'm facing is intermittent. Sometimes it works fine, but other times it acts up unexpectedly.
#
# --- Ticket 56 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# Thanks
#
# Brianna D.
#
# Founder, RVA Systems, Inc
#
# Senior Designer
#
# Caitlin
#
# Senior Designer I've checked the device settings and made sure that everything is configured correctly.
#
# --- Ticket 57 ---
# I'm having an issue with the {product_purchased}. Please assist. I'm sorry if that might be a bad idea, but I'd rather not have it.
#
# Sierra: Thank you so much for your time and help I've noticed a peculiar error message popping up on my {product_purchased} screen. It says '{error_message}'. What does it mean?
#
# --- Ticket 58 ---
# I'm having an issue with the {product_purchased}. Please assist. 1:14pm CDT by Akshay Mistry from New York - Akshay Mistry (aka Akshay) The book is about the life I've checked for software updates, and my {product_purchased} is already running the latest version.
#
# --- Ticket 59 ---
# I'm facing a problem with my {product_purchased}. The {product_purchased} is not turning on. It was working fine until yesterday, but now it doesn't respond.
#
#
# What is the solution at the moment I've tried troubleshooting steps mentioned in the user manual, but the issue persists.
#
# --- Ticket 60 ---
# I'm having an issue with the {product_purchased}. Please assist. You will need:
#
# a package with an id that must appear at the start of the URL
#
# an ID of the product that you wanted to obtain I'm unable to find the option to perform the desired action in the {product_purchased}. Could you please guide me through the steps?
#
# --- Ticket 61 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# {product_purchased}.add to ProductID, ( ProductId = ProductID ).isValid, ( itemId = ProductId ) I've tried troubleshooting steps mentioned in the user manual, but the issue persists.
#
# --- Ticket 62 ---
# I'm having an issue with the {product_purchased}. Please assist. I've performed a factory reset on my {product_purchased}, hoping it would resolve the problem, but it didn't help.
#
# --- Ticket 63 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# Thanks! I've tried using different cables, adapters, or peripherals with my {product_purchased}, but the issue persists.
#
# --- Ticket 64 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# The items can not be backordered due to how they were received.
#
# You will receive tracking information when you first log on to this site. I've followed the troubleshooting steps mentioned in the user manual, but the issue persists.
#
# --- Ticket 65 ---
# There seems to be a hardware problem with my {product_purchased}. The screen is flickering, and I'm unable to use it. What should I do?
#
# What about any other devices that have a broken resolution?
#
# What The issue I'm facing is intermittent. Sometimes it works fine, but other times it acts up unexpectedly.
#
# --- Ticket 66 ---
# I've accidentally deleted important data from my {product_purchased}. Is there any way to recover the deleted files? I need them urgently. Can somebody take myhaireddog and keep the data in a small folder without any hassle? I've checked for any available software updates for my {product_purchased}, but there are none.
#
# --- Ticket 67 ---
# I'm having an issue with the {product_purchased}. Please assist. Please help us in solving this problem. This is why we need your help. Contact us soon.
#
# Our Customer Service
#
# The Products and Services Customer Service I've noticed a peculiar error message popping up on my {product_purchased} screen. It says '{error_message}'. What does it mean?
#
# --- Ticket 68 ---
# I'm having an issue with the {product_purchased}. Please assist.
#
# The product name is'mall', which means for example 'Plum' or 'Felise', if the product has been 'paid for' The issue I'm facing is intermittent. Sometimes it works fine, but other times it acts up unexpectedly.
#
# --- Ticket 69 ---
# The {product_purchased} is unable to establish a stable internet connection. It keeps disconnecting intermittently. How can I troubleshoot this network problem?
#
# Try:
#
# $ docker run -d # Create a Dockerfile I've recently updated the firmware of my {product_purchased}, and the issue started happening afterward. Could it be related to the update?
#
# --- Ticket 70 ---
# I'm having an issue with the {product_purchased}. Please assist. If the product is not already stocked, I may need to charge another retail price. Your order will be shipped as soon as the items are sorted. I apologize for I've followed online tutorials and community forums to troubleshoot the issue, but no luck so far.

# %%
import pandas as pd

path = "/content/drive/MyDrive/SupportOpsAI/data/kaggle_raw/ticket_helpdesk_labeled_multi_languages_english_spain_french_german.csv"

df = pd.read_csv(path)

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Shape: (200, 8)
#
# Columns:
# ['queue', 'priority', 'software_used', 'hardware_used', 'accounting_category', 'language', 'subject', 'text']

# %%
df.head()
# Out:
#         queue  priority software_used   hardware_used  \
# 0    Hardware         2           NaN  Wireless Mouse
# 1    Hardware         2           NaN          IP PBX
# 2    Hardware         2           NaN    SFX-Netzteil
# 3  Accounting         2           NaN             NaN
# 4    Software         2      Arbitrum             NaN
#
#                      accounting_category language  \
# 0                                    NaN       en
# 1                                    NaN       fr
# 2                                    NaN       de
# 3  Customer Inquiries::Technical Support       en
# 4                                    NaN       en
#
#                                  subject  \
# 0  Wireless Mouse suddenly stops working
# 1          Problème de connexions IP PBX
# 2        Problem mit meinem SFX-Netzteil
# 3             Invoice Adjustment Request
# 4    Issue with Arbitrum: UI not loading
#
#                                                 text
# 0  Dear Support Team, I've been using the Wireles...
# 1  Bonjour, nous rencontrons un problème avec not...
# 2  Sehr geehrte Damen und Herren, mein SFX-Netzte...
# 3  Dear Customer Support,\nI recently received my...
# 4  Hello Support Team,\nI've been experiencing an...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   queue                200 non-null    object
#  1   priority             200 non-null    int64
#  2   software_used        83 non-null     object
#  3   hardware_used        66 non-null     object
#  4   accounting_category  51 non-null     object
#  5   language             200 non-null    object
#  6   subject              200 non-null    object
#  7   text                 200 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 12.6+ KB

# %%
english_df = df[df["language"] == "en"].copy()

print("English tickets:", len(english_df))
print("\nQueues:")
print(english_df["queue"].value_counts())

print("\nPriorities:")
print(english_df["priority"].value_counts())
# Out:
# English tickets: 78
#
# Queues:
# queue
# Hardware      33
# Software      23
# Accounting    22
# Name: count, dtype: int64
#
# Priorities:
# priority
# 3    32
# 2    29
# 1    17
# Name: count, dtype: int64

# %%
english_df[["queue", "priority", "subject", "text"]].head(10)
# Out:
#          queue  priority                                            subject  \
# 0     Hardware         2              Wireless Mouse suddenly stops working
# 3   Accounting         2                         Invoice Adjustment Request
# 4     Software         2                Issue with Arbitrum: UI not loading
# 9     Hardware         2    Issue with Portable Console - Screen flickering
# 10    Hardware         2               Issue with NAS enclosure temperature
# 11  Accounting         2  Invoice Query: Changing Corporate Billing Details
# 13  Accounting         3               Issue with expense report submission
# 18  Accounting         2            Timesheet entry software malfunctioning
# 19    Hardware         3        Critical: Smart Pet Camera Complete Failure
# 20    Hardware         3  URGENT: USB-HUB malfunctioning - Need Assistan...
#
#                                                  text
# 0   Dear Support Team, I've been using the Wireles...
# 3   Dear Customer Support,\nI recently received my...
# 4   Hello Support Team,\nI've been experiencing an...
# 9            The screen flickers randomly during use.
# 10  Hello Support, my NAS enclosure is overheating...
# 11  Dear Support Team,\nI am writing to request a ...
# 13  Dear Accounting Team, I am having trouble subm...
# 18  Hello support team, our employees can't access...
# 19  Hello Support,\nMy Smart Pet Camera suddenly s...
# 20  Dear Support Team,My new USB-Hub, Model Q35-T,...

# %%
from datasets import load_dataset

hf_dataset = load_dataset(
    "Tobi-Bueck/customer-support-tickets",
    split="train"
)

print(hf_dataset)
# Out:
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
#   warnings.warn(f"\nError while fetching `HF_TOKEN` secret value from your vault: '{str(e)}'.")
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/7.75k [00:00<?, ?B/s]
# aa_dataset-tickets-multi-lang-5-2-50-ver(…): reconstructing file:   0%|          |  0.00B / 26.0MB
# aa_dataset-tickets-multi-lang-5-2-50-ver(…): downloading bytes:           |  0.00B
# (…)set-tickets-german_normalized_50_5_2.csv:   0%|          | 0.00/8.33M [00:00<?, ?B/s]
# dataset-tickets-multi-lang-4-20k.csv: reconstructing file:   0%|          |  0.00B / 18.8MB
# dataset-tickets-multi-lang-4-20k.csv: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/61765 [00:00<?, ? examples/s]
# Dataset({
#     features: ['subject', 'body', 'answer', 'type', 'queue', 'priority', 'language', 'version', 'tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5', 'tag_6', 'tag_7', 'tag_8'],
#     num_rows: 61765
# })

# %%
print(hf_dataset.column_names)
print(hf_dataset[0])
# Out:
# ['subject', 'body', 'answer', 'type', 'queue', 'priority', 'language', 'version', 'tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5', 'tag_6', 'tag_7', 'tag_8']
# {'subject': 'Wesentlicher Sicherheitsvorfall', 'body': 'Sehr geehrtes Support-Team,\\n\\nich möchte einen gravierenden Sicherheitsvorfall melden, der gegenwärtig mehrere Komponenten unserer Infrastruktur betrifft. Betroffene Geräte umfassen Projektoren, Bildschirme und Speicherlösungen auf Cloud-Plattformen. Der Grund für die Annahme ist, dass der Vorfall eine potenzielle Datenverletzung im Zusammenhang mit einer Cyberattacke darstellt, was ein erhebliches Risiko für sensible Informationen und den laufenden Geschäftsbetrieb unserer Organisation bedeutet.\\n\\nUnsere initialen Untersuchungen haben ungewöhnliche Aktivitäten und Abweichungen bei den Geräten ergeben. Trotz der Umsetzung unserer standardisierten Behebungs- und Eindämmungsmaßnahmen konnte die Bedrohung bislang nicht vollständig eliminiert.', 'answer': 'Vielen Dank für die Meldung des kritischen Sicherheitsvorfalls und die Bereitstellung der Übersicht über die betroffenen Geräte sowie der ergriffenen ersten Maßnahmen. Wir erkennen die Dringlichkeit und Schwere der Lage an und setzen alles daran, den Fall prioritär zu bearbeiten. Für eine umgehende Untersuchung benötigen wir zusätzliche Informationen: Bitte senden Sie uns spezifische Protokolle der betroffenen Projektoren, Bildschirme und Cloud-Speichersysteme, inklusive Zeitstempel verdächtiger Aktivitäten sowie ungewöhnlicher Fehlermeldungen. Falls möglich, fügen Sie auch eine Zusammenfassung der bereits durchgeführten Maßnahmen bei.', 'type': 'Incident', 'queue': 'Technical Support', 'priority': 'high', 'language': 'de', 'version': 51, 'tag_1': 'Security', 'tag_2': 'Outage', 'tag_3': 'Disruption', 'tag_4': 'Data Breach', 'tag_5': None, 'tag_6': None, 'tag_7': None, 'tag_8': None}

# %%
import pandas as pd

tickets_df = hf_dataset.to_pandas()

print(tickets_df.shape)
tickets_df.head()
# Out:
# (61765, 16)
#                                              subject  \
# 0                    Wesentlicher Sicherheitsvorfall
# 1                                 Account Disruption
# 2  Query About Smart Home System Integration Feat...
# 3                  Inquiry Regarding Invoice Details
# 4  Question About Marketing Agency Software Compa...
#
#                                                 body  \
# 0  Sehr geehrtes Support-Team,\n\nich möchte eine...
# 1  Dear Customer Support Team,\n\nI am writing to...
# 2  Dear Customer Support Team,\n\nI hope this mes...
# 3  Dear Customer Support Team,\n\nI hope this mes...
# 4  Dear Support Team,\n\nI hope this message reac...
#
#                                               answer      type  \
# 0  Vielen Dank für die Meldung des kritischen Sic...  Incident
# 1  Thank you for reaching out, <name>. We are awa...  Incident
# 2  Thank you for your inquiry. Our products suppo...   Request
# 3  We appreciate you reaching out with your billi...   Request
# 4  Thank you for your inquiry. Our product suppor...   Problem
#
#                    queue priority language  version     tag_1       tag_2  \
# 0      Technical Support     high       de     51.0  Security      Outage
# 1      Technical Support     high       en     51.0   Account  Disruption
# 2  Returns and Exchanges   medium       en     51.0   Product     Feature
# 3   Billing and Payments      low       en     51.0   Billing     Payment
# 4    Sales and Pre-Sales   medium       en     51.0   Product     Feature
#
#           tag_3          tag_4         tag_5 tag_6 tag_7 tag_8
# 0    Disruption    Data Breach          None  None  None  None
# 1        Outage             IT  Tech Support  None  None  None
# 2  Tech Support           None          None  None  None  None
# 3       Account  Documentation      Feedback  None  None  None
# 4      Feedback   Tech Support          None  None  None  None

# %%
print("Languages:")
print(tickets_df["language"].value_counts())

print("\nQueues:")
print(tickets_df["queue"].value_counts())

print("\nPriorities:")
print(tickets_df["priority"].value_counts())

print("\nTypes:")
print(tickets_df["type"].value_counts())
# Out:
# Languages:
# language
# de    33504
# en    28261
# Name: count, dtype: int64
#
# Queues:
# queue
# Technical Support                         14186
# Product Support                            8960
# Customer Service                           7420
# IT Support                                 5725
# Billing and Payments                       4874
# Returns and Exchanges                      2438
# Service Outages and Maintenance            1912
# Sales and Pre-Sales                        1490
# Human Resources                             914
# General Inquiry                             668
# Pets & Animals/Pet Services                 386
# News                                        383
# IT & Technology/Security Operations         365
# Autos & Vehicles/Sales                      364
# Health/Medical Services                     362
# Home & Garden/Home Improvement              361
# Pets & Animals/Veterinary Care              356
# Health/Mental Health                        347
# Business & Industrial/Manufacturing         346
# Online Communities/Forums                   343
# Shopping/E-commerce                         341
# Food & Drink/Groceries                      332
# Travel & Transportation/Land Travel         331
# Jobs & Education/Online Courses             329
# Finance/Investments                         327
# Law & Government/Government Services        326
# Hobbies & Leisure/Collectibles              325
# Online Communities/Social Networks          322
# Books & Literature/Non-Fiction              320
# Science/Environmental Science               318
# Hobbies & Leisure/Crafts                    316
# Finance/Personal Finance                    312
# Science/Research                            310
# IT & Technology/Network Infrastructure      302
# Games                                       301
# Travel & Transportation/Air Travel          300
# Beauty & Fitness/Cosmetics                  300
# Arts & Entertainment/Music                  298
# Food & Drink/Restaurants                    295
# Law & Government/Legal Advice               294
# Autos & Vehicles/Maintenance                293
# IT & Technology/Hardware Support            293
# Jobs & Education/Recruitment                290
# Books & Literature/Fiction                  289
# Beauty & Fitness/Fitness Training           289
# Shopping/Retail Stores                      283
# People & Society/Culture & Society          283
# Arts & Entertainment/Movies                 262
# IT & Technology/Software Development        262
# Home & Garden/Landscaping                   256
# Sports                                      236
# Real Estate                                 230
# Name: count, dtype: int64
#
# Priorities:
# priority
# medium      23378
# high        21925
# low         12765
# critical     1914
# very_low     1783
# Name: count, dtype: int64
#
# Types:
# type
# Incident    19444
# Request     13950
# Problem     10196
# Change       4997
# Name: count, dtype: int64

# %%
print("Number of queues:", tickets_df["queue"].nunique())
print("Number of priorities:", tickets_df["priority"].nunique())
print("Number of types:", tickets_df["type"].nunique())
# Out:
# Number of queues: 52
# Number of priorities: 5
# Number of types: 4

# %%
print(tickets_df.isnull().sum())
# Out:
# subject      5299
# body            2
# answer      13189
# type        13178
# queue           0
# priority        0
# language        0
# version     33178
# tag_1       13178
# tag_2       13237
# tag_3       13409
# tag_4       17775
# tag_5       34129
# tag_6       48540
# tag_7       55797
# tag_8       59293
# dtype: int64

# %%
print("Duplicate subjects:", tickets_df["subject"].duplicated().sum())
print("Duplicate bodies:", tickets_df["body"].duplicated().sum())
# Out:
# Duplicate subjects: 15129
# Duplicate bodies: 8400

# %%
print(
    tickets_df.groupby("version").size().sort_values(ascending=False).head(20)
)
# Out:
# version
# 400.0    18599
# 52.0      9119
# 51.0       869
# dtype: int64

# %%
pd.set_option("display.max_colwidth", 300)

tickets_df[["subject", "body", "queue", "priority", "type", "answer"]].sample(
    10, random_state=42
)
# Out:
#                                                                            subject  \
# 59903                                     Sicherheitsverstoß im Krankenhaus-System
# 24200                                                Trouble with WhatsApp Desktop
# 35048                                   Sporadische Scannerfehler am Point of Sale
# 31808                            Markt-Alarm-Verzögerungen in der Handelsplattform
# 29641                                     Probleme bei der Buchung von Proberäumen
# 15142                     Integration with Discord for Enhanced Team Collaboration
# 59042                                   Enhancements for Safeguarding Medical Data
# 29088        Wichtig: EV-Buchungssystem derzeit nicht verfügbar, betrifft Benutzer
# 24499                     Details zu Digitalen Strategieleistungen für Markengröße
# 61309  Issue with System Downtime Affecting Data Analytics Investment Optimization
#
#                                                                                                                                                                                                                                                                                                               body  \
# 59903                                                                                                                                                                                                           Es wurde ein Sicherheitsverstoß festgestellt, der die Sicherheit der Patientendaten gefährdet hat.
# 24200  Experienced technical difficulties during a marketing campaign coordination call involving WhatsApp Desktop. The issue might have arisen from recent software updates. Tried reinstalling the application and rebooting the system, but the problem still persists. We would appreciate your assistance ...
# 35048  Sehr geehrtes Support-Team,\n\nich schreibe Ihnen, um ein wiederkehrendes Problem mit dem Barcode-Scanner an unserer Kasse zu melden. Der Scanner weist zeitweise Fehlfunktionen auf, was zu Preisungenauigkeiten während des Bezahlvorgangs führt. Dieses Problem ist besonders angesichts unserer aktu...
# 31808  Hallo Support-Team,\n\nich schreibe Ihnen, um ein Problem zu melden, das ich mit der Fidelity Active Trader Pro Plattform habe. Ich habe zeitweise Verzögerungen beim Empfang von Markt-Alarmen festgestellt. SilverLine Finance hat darauf hingewiesen, dass dies ein bekanntes Problem mit einer mögli...
# 29641  Hallo Support,\n\nwir haben derzeit einige Fehlermeldungen beim Versuch, Proberäume über das Online-System zu buchen. Für dringende Buchungen gibt es eine temporäre Lösung über die Theaterkasse. Wir gehen davon aus, dass dieses Problem innerhalb der nächsten 24 Stunden behoben sein wird.\n\nViel...
# 15142  Inquiring about the process of integrating Discord into our project management SaaS to improve team collaboration. Would appreciate guidance on the specific features that will be available and the benefits of using Discord for team collaboration. Please provide details on the steps required to i...
# 59042  Customer Support, please address the implementation of security enhancements for protecting medical data across hospital systems and related software products. Given the importance of safeguarding sensitive medical information, we believe it is essential that appropriate measures are taken to pr...
# 29088                                                                                                                                                                                                            An das Support-Team,\n\nwir haben derzeit Schwierigkeiten mit dem Buchungssystem der mobilen App.
# 24499  Könnten Sie mehr Details zu den digitalen Strategieleistungen für Markengröße geben? Wir sind an der Möglichkeit interessiert, mehr über die Leistungen unserer Firma zu erfahren, um unsere Onlinepräsenz zu erweitern und neue Kunden zu erreichen. Danke für Ihre Zeit und ich freue mich auf Ihre Rü...
# 61309  Hello Customer Support, I am currently working on a report that highlights an unexpected system downtime which is impacting our data analytics investment optimization. The problem might be due to resource overload on Microsoft Azure. Despite my attempts to restart Docker containers and clear cac...
#
#                              queue priority      type  \
# 59903            Technical Support     high  Incident
# 24200            Technical Support   medium  Incident
# 35048       Shopping/Retail Stores      low      None
# 31808          Finance/Investments   medium      None
# 29641                       Sports   medium      None
# 15142             Customer Service     high   Request
# 59042                   IT Support   medium    Change
# 29088  Pets & Animals/Pet Services     high      None
# 24499            Technical Support     high   Request
# 61309             Customer Service   medium  Incident
#
#                                                                                                                                                                                                                                                                                                             answer
# 59903                                                                                                                                Wir werden dringend Maßnahmen ergreifen, um die Situation zu kontrollieren, die Untersuchung der Verletzung durchzuführen und den Schutz der Patientendaten zu gewährleisten.
# 24200  Hello [Name],\n\nWe hope this email finds you well. We are writing to acknowledge the issue you encountered with WhatsApp Desktop during your marketing campaign coordination call. We sincerely apologize for any inconvenience this has caused.\n\nTo better assist you, we would like to gather more ...
# 35048                                                                                                                                                                                                                                                                                                         None
# 31808                                                                                                                                                                                                                                                                                                         None
# 29641                                                                                                                                                                                                                                                                                                         None
# 15142  <name> appreciates your interest in integrating Discord into the project management SaaS to enhance team collaboration. To set up the integration, navigate to the integrations section within the SaaS and select Discord from the list of available integrations. You will then be prompted to authori...
# 59042  We appreciate your concern regarding the protection of medical data and will provide you with information on the current security protocols and future enhancements, including encryption methods and access controls. We will provide your account number and please specify your preferred time for a ...
# 29088                                                                                                                                                                                                                                                                                                         None
# 24499  Sehr geehrte [Name], vielen Dank für Ihr Interesse an unseren digitalen Strategieleistungen für Markengröße. Unsere Leistungen umfassen Webseitenentwicklung, Suchmaschinenoptimierung, Sozialmedienmanagement und Online-Marketingkampagnen, um Ihre Onlinepräsenz zu erweitern und neue Kunden zu erre...
# 61309                                                                                                                     We will investigate the Microsoft Azure resource overload issue and contact us at <tel_num> to discuss the resolution steps. Please provide your account number <acc_num> for reference.

# %%
# Look at exact duplicate subject + body combinations

ticket_text = (
    tickets_df["subject"].fillna("") + " " +
    tickets_df["body"].fillna("")
)

print("Exact duplicate subject+body:", ticket_text.duplicated().sum())
# Out:
# Exact duplicate subject+body: 8306

# %%
temp = tickets_df.copy()

temp["ticket_text"] = (
    temp["subject"].fillna("") + " " +
    temp["body"].fillna("")
)

duplicate_groups = (
    temp.groupby("ticket_text")
    .agg(
        count=("ticket_text", "size"),
        queues=("queue", "nunique"),
        priorities=("priority", "nunique")
    )
)

print("Duplicate groups with conflicting queues:")
print(
    duplicate_groups[
        (duplicate_groups["count"] > 1) &
        (duplicate_groups["queues"] > 1)
    ].head(20)
)
# Out:
# Duplicate groups with conflicting queues:
# Empty DataFrame
# Columns: [count, queues, priorities]
# Index: []

# %%
print("Duplicate groups with conflicting priorities:")
print(
    duplicate_groups[
        (duplicate_groups["count"] > 1) &
        (duplicate_groups["priorities"] > 1)
    ].head(20)
)
# Out:
# Duplicate groups with conflicting priorities:
# Empty DataFrame
# Columns: [count, queues, priorities]
# Index: []

# %%
en_df = tickets_df[
    tickets_df["language"] == "en"
].copy()

print(en_df.shape)
# Out:
# (28261, 16)

# %%
print("English queue distribution:")
print(en_df["queue"].value_counts())
# Out:
# English queue distribution:
# queue
# Technical Support                  8149
# Product Support                    5305
# Customer Service                   4269
# IT Support                         3333
# Billing and Payments               2897
# Returns and Exchanges              1402
# Service Outages and Maintenance    1106
# Sales and Pre-Sales                 843
# Human Resources                     553
# General Inquiry                     404
# Name: count, dtype: int64

# %%
print("English priority distribution:")
print(en_df["priority"].value_counts())
# Out:
# English priority distribution:
# priority
# medium    11570
# high      10917
# low        5774
# Name: count, dtype: int64

# %%
print(
    en_df.groupby("queue")["priority"]
    .value_counts()
    .head(30)
)
# Out:
# queue                            priority
# Billing and Payments             medium      1436
#                                  high         846
#                                  low          615
# Customer Service                 medium      2077
#                                  low         1403
#                                  high         789
# General Inquiry                  low          239
#                                  medium        99
#                                  high          66
# Human Resources                  low          263
#                                  medium       232
#                                  high          58
# IT Support                       high        1580
#                                  medium      1424
#                                  low          329
# Product Support                  medium      2693
#                                  high        1600
#                                  low         1012
# Returns and Exchanges            medium       570
#                                  low          517
#                                  high         315
# Sales and Pre-Sales              medium       389
#                                  low          304
#                                  high         150
# Service Outages and Maintenance  high         776
#                                  medium       189
#                                  low          141
# Technical Support                high        4737
#                                  medium      2461
#                                  low          951
# Name: count, dtype: int64

# %%
print(
    tickets_df["version"]
    .value_counts()
    .sort_index()
)
# Out:
# version
# 51.0       869
# 52.0      9119
# 400.0    18599
# Name: count, dtype: int64

# %%
print(
    tickets_df.groupby(["version", "language"]).size()
)
# Out:
# version  language
# 51.0     de            318
#          en            551
# 52.0     de           3773
#          en           5346
# 400.0    de           8158
#          en          10441
# dtype: int64

# %%
print("Number of English queues:", en_df["queue"].nunique())

print("\nSmallest English queues:")
print(
    en_df["queue"]
    .value_counts()
    .sort_values()
    .head(20)
)
# Out:
# Number of English queues: 10
#
# Smallest English queues:
# queue
# General Inquiry                     404
# Human Resources                     553
# Sales and Pre-Sales                 843
# Service Outages and Maintenance    1106
# Returns and Exchanges              1402
# Billing and Payments               2897
# IT Support                         3333
# Customer Service                   4269
# Product Support                    5305
# Technical Support                  8149
# Name: count, dtype: int64

# %%
en_df["ticket_text"] = (
    en_df["subject"].fillna("") + "\n" +
    en_df["body"].fillna("")
)

print("English rows:", len(en_df))
print("Unique English tickets:", en_df["ticket_text"].nunique())
print("Duplicate English rows:", en_df["ticket_text"].duplicated().sum())
# Out:
# English rows: 28261
# Unique English tickets: 23748
# Duplicate English rows: 4513

# %%
print("\nDuplicates by version:")
print(
    en_df.groupby("version")["ticket_text"]
    .apply(lambda x: x.duplicated().sum())
)
# Out:
# Duplicates by version:
# version
# 51.0     0
# 52.0     0
# 400.0    0
# Name: ticket_text, dtype: int64

# %%
clean_df = en_df.copy()

# Remove exact duplicate tickets
clean_df = clean_df.drop_duplicates(
    subset=["subject", "body"]
).copy()

print("Before:", len(en_df))
print("After:", len(clean_df))
print("Removed:", len(en_df) - len(clean_df))
# Out:
# Before: 28261
# After: 23748
# Removed: 4513

# %%
print("Queue distribution:")
print(clean_df["queue"].value_counts())

print("\nPriority distribution:")
print(clean_df["priority"].value_counts())
# Out:
# Queue distribution:
# queue
# Technical Support                  6858
# Product Support                    4430
# Customer Service                   3570
# IT Support                         2833
# Billing and Payments               2420
# Returns and Exchanges              1173
# Service Outages and Maintenance     937
# Sales and Pre-Sales                 724
# Human Resources                     461
# General Inquiry                     342
# Name: count, dtype: int64
#
# Priority distribution:
# priority
# medium    9754
# high      9149
# low       4845
# Name: count, dtype: int64

# %%
print(
    pd.crosstab(
        clean_df["queue"],
        clean_df["priority"]
    )
)
# Out:
# priority                         high   low  medium
# queue
# Billing and Payments              714   515    1191
# Customer Service                  666  1169    1735
# General Inquiry                    54   202      86
# Human Resources                    49   220     192
# IT Support                       1334   278    1221
# Product Support                  1318   845    2267
# Returns and Exchanges             252   446     475
# Sales and Pre-Sales               126   258     340
# Service Outages and Maintenance   661   116     160
# Technical Support                3975   796    2087

# %%
print("Missing subjects:", clean_df["subject"].isna().sum())
print("Missing bodies:", clean_df["body"].isna().sum())
# Out:
# Missing subjects: 2827
# Missing bodies: 1

# %%
clean_df[
    ["subject", "body", "queue", "priority"]
].sample(10, random_state=42)
# Out:
#                                                                                        subject  \
# 28221                Detected Unauthorized Access to Medical Data System Due to Phishing Email
# 58261                                                                Report on Invoicing Error
# 23984                                                 Problem with Real-Time Data Presentation
# 24843                               Report on Data Security Incident Involving Medical Records
# 6122   Underwhelming Results of Digital Campaigns Due to Cross-Platform Integration Challenges
# 46560                                                    Issues Arising from Heavy System Load
# 52174                                                          Project Timeline Not Displaying
# 694                 Immediate Attention Required: Network Disruption Impacting Several Devices
# 5894                                                        Hospital Network Security Concerns
# 41995                                                                        Technical Support
#
#                                                                                                                                                                                                                                                                                                               body  \
# 28221                                                                                                                                                                                                     Initial security protocols were activated following an unauthorized access attempt via a phishing email.
# 58261  Respected Customer Support, I am contacting you to report a problem with the invoices I recently received. I was overcharged for the same service twice, which might indicate a problem with the billing system. Despite reaching out to support and reviewing my invoices online, the issue remains unr...
# 23984                                                                                  The digital marketing analytics tool, which was supposed to display live data after the recent system update, is not functioning as expected. I have tried refreshing and clearing the cache, but the issue still persists.
# 24843                                                                                             There has been a data security incident affecting medical records due to a software vulnerability which might have exposed the records. Despite updating protocols and conducting scans, the issue still exists.
# 6122   Customer Support, preparing a report on the digital campaigns managed by the marketing agency, which have underperformed potentially because of integration problems across various platforms. We tested platform synchronization and updated the software; however, the issues continue. Our team is wo...
# 46560  There have been multiple instances of software crashes happening at the same time. It is suspected that the system is overloaded, leading to these crashes. Efforts to resolve the issue, such as restarting devices and updating software, have been made but the problem still exists. I need your hel...
# 52174                                                                                                                                                                                                                      The project timeline view is not displaying because of a database connectivity problem.
# 694    Dear Customer Support Team,\n\nI am submitting a report regarding a significant network interruption currently disrupting several devices. The cause appears to be either hardware or network-related. Despite our efforts, we have been unable to pinpoint or resolve the fundamental issue.\n\nTo diag...
# 5894   Customer support has documented an incident involving unauthorized access attempts aimed at the hospital's sensitive medical data storage systems. The healthcare provider has indicated that these attempts may be linked to vulnerabilities in outdated PHP 8.0 and unpatched Git 2.32 software. Initi...
# 41995  Reporting intermittent performance issues on the SaaS platform while accessing project files. The issue might be related to insufficient RAM or network instability, especially with NAS wireless connections. Despite restarting networking equipment and optimizing storage settings, the problem pers...
#
#                                  queue priority
# 28221                 Customer Service   medium
# 58261             Billing and Payments   medium
# 23984                       IT Support   medium
# 24843                Technical Support   medium
# 6122                  Customer Service      low
# 46560                Technical Support     high
# 52174                Technical Support   medium
# 694    Service Outages and Maintenance     high
# 5894                 Technical Support      low
# 41995                 Customer Service      low

# %%
missing_subject = clean_df[
    clean_df["subject"].isna()
]

print("Missing subject rows:", len(missing_subject))

missing_subject[
    ["subject", "body", "queue", "priority"]
].sample(10, random_state=42)
# Out:
# Missing subject rows: 2827
#       subject  \
# 16938    None
# 8602     None
# 28487    None
# 5441     None
# 20182    None
# 4750     None
# 26143    None
# 4641     None
# 6461     None
# 18569    None
#
#                                                                                                                                                                                                                                                                                                               body  \
# 16938  Customer Support, I am facing connectivity issues with my Streaming-Kamera and WLAN-Router. This could possibly be due to network configuration errors. I have already rebooted the devices and checked the network settings, but the problem still persists. I am unable to establish a stable connecti...
# 8602   Customer Support, I am reaching out to inquire about integrating a scalable SaaS project management platform with WordPress and BigCommerce. Could you provide comprehensive documentation on the process? I want to understand the steps involved and any potential challenges that might occur. Specif...
# 28487                                                                                                                                                       May I request more information on the data analytics services that optimize investments? Your prompt assistance on this matter is greatly appreciated.
# 5441                                                Customer support, experiencing difficulties in retrieving pricing information. Recent updates to the website might be the cause. I have attempted clearing the cache and used various browsers, but the issue persists. Kindly help in resolving this problem.
# 20182  Customer Support, requesting enhancements to integration features across affected products to better streamline project management workflows and make it easier for teams to collaborate and track progress. Currently, the lack of seamless integration is causing inefficiencies and delays in project...
# 4750   expressing curiosity about integrating RapidMiner into the current data analytics infrastructure. currently utilize a variety of tools and platforms to manage and analyze data, and are keen on exploring how RapidMiner can enhance these capabilities. Would greatly appreciate any guidance on the b...
# 26143  Customer Support, we are reporting an incident related to a decrease in client engagement metrics over the past month. It is possible that recent algorithm changes on social media platforms could be the cause. Despite efforts to improve content quality and increase ad spending, there have been n...
# 4641   Customer Support, I am reaching out to inquire about best practices for securing medical data within healthcare environments using Cassandra 4.0. Could you please provide guidance on this topic? I would appreciate any information you can share. Thank you for your time and assistance. I look forw...
# 6461   Experiencing a report problem with digital tools integration that is affecting campaign execution. The issue seems to be linked to incompatible or outdated software versions. Attempts to fix the problem included updating Node.js, reinstalling Joomla, and troubleshooting OBS Studio configurations...
# 18569  Dear Customer Support, I would like to draw your attention to a pressing matter concerning a security breach in the systems of our healthcare provider. Sensitive medical data has been compromised, and I am extremely concerned about the potential consequences. Initial investigation indicates that...
#
#                      queue priority
# 16938    Technical Support     high
# 8602       Product Support   medium
# 28487     Customer Service   medium
# 5441   Sales and Pre-Sales      low
# 20182      Product Support     high
# 4750     Technical Support     high
# 26143     Customer Service      low
# 4641     Technical Support     high
# 6461      Customer Service     high
# 18569     Customer Service   medium

# %%
print(
    "Missing subject + missing body:",
    missing_subject["body"].isna().sum()
)
# Out:
# Missing subject + missing body: 0

# %%
missing_subject["body"].str.len().describe()
# Out:
# count    2827.000000
# mean      427.784577
# std       181.104944
# min         4.000000
# 25%       301.000000
# 50%       482.000000
# 75%       555.000000
# max      1702.000000
# Name: body, dtype: float64

# %%
print("Queues:")
print(missing_subject["queue"].value_counts())

print("\nPriorities:")
print(missing_subject["priority"].value_counts())
# Out:
# Queues:
# queue
# Technical Support                  821
# Product Support                    509
# Customer Service                   394
# IT Support                         368
# Billing and Payments               267
# Returns and Exchanges              145
# Sales and Pre-Sales                118
# Service Outages and Maintenance     90
# Human Resources                     64
# General Inquiry                     51
# Name: count, dtype: int64
#
# Priorities:
# priority
# high      1131
# medium    1119
# low        577
# Name: count, dtype: int64

# %%
# Make a clean copy
final_df = clean_df.copy()

# Remove the one ticket with no body
final_df = final_df.dropna(subset=["body"]).copy()

# Keep missing subjects for now
# We will handle them during training-data preparation

print("Final clean dataset:", final_df.shape)
print("Missing subjects:", final_df["subject"].isna().sum())
print("Missing bodies:", final_df["body"].isna().sum())
# Out:
# Final clean dataset: (23747, 17)
# Missing subjects: 2827
# Missing bodies: 0

# %%
final_df = final_df[
    ["subject", "body", "queue", "priority", "language", "version"]
].copy()

# %%
import os

processed_dir = "/content/drive/MyDrive/SupportOpsAI/data/processed"

os.makedirs(processed_dir, exist_ok=True)

clean_path = os.path.join(
    processed_dir,
    "english_clean.csv"
)

final_df.to_csv(clean_path, index=False)

print(f"Saved to: {clean_path}")
# Out:
# Saved to: /content/drive/MyDrive/SupportOpsAI/data/processed/english_clean.csv

# %%
check_df = pd.read_csv(clean_path)

print(check_df.shape)
print(check_df.head())
# Out:
# (23747, 6)
#                                                   subject  \
# 0                                      Account Disruption
# 1      Query About Smart Home System Integration Features
# 2                       Inquiry Regarding Invoice Details
# 3  Question About Marketing Agency Software Compatibility
# 4                                           Feature Query
#
#                                                                                                                                                                                                                                                                                                           body  \
# 0  Dear Customer Support Team,\n\nI am writing to report a significant problem with the centralized account management portal, which currently appears to be offline. This outage is blocking access to account settings, leading to substantial inconvenience. I have attempted to log in multiple times u...
# 1  Dear Customer Support Team,\n\nI hope this message reaches you well. I am reaching out to request detailed information about the capabilities of your smart home integration products listed on your website. As a potential customer aiming to develop a seamlessly interconnected home environment, it...
# 2  Dear Customer Support Team,\n\nI hope this message finds you well. I am reaching out to request clarification about the billing and payment procedures linked to my account. Recently, I observed some inconsistencies in the charges applied and would like to ensure I fully understand the billing cy...
# 3  Dear Support Team,\n\nI hope this message reaches you well. I am reaching out to ask about the compatibility of your products with the specific needs of marketing agencies. Our company is considering adopting these solutions to streamline our current marketing processes and wants to confirm that...
# 4  Dear Customer Support,\n\nI hope this message reaches you in good health. I am eager to learn more about the features of one of your products. Would you be able to share comprehensive details about its functionalities, specifications, and any distinctive characteristics it may possess? Additiona...
#
#                    queue priority language  version
# 0      Technical Support     high       en     51.0
# 1  Returns and Exchanges   medium       en     51.0
# 2   Billing and Payments      low       en     51.0
# 3    Sales and Pre-Sales   medium       en     51.0
# 4      Technical Support     high       en     51.0

# %%
# !ls
# Out:
# sample_data

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

clean_path = "/content/drive/MyDrive/SupportOpsAI/data/processed/english_clean.csv"

final_df = pd.read_csv(clean_path)

print(final_df.shape)
print(final_df.columns)
# Out:
# (23747, 6)
# Index(['subject', 'body', 'queue', 'priority', 'language', 'version'], dtype='object')

# %%
print(final_df["queue"].value_counts())
print()
print(final_df["priority"].value_counts())
# Out:
# queue
# Technical Support                  6858
# Product Support                    4429
# Customer Service                   3570
# IT Support                         2833
# Billing and Payments               2420
# Returns and Exchanges              1173
# Service Outages and Maintenance     937
# Sales and Pre-Sales                 724
# Human Resources                     461
# General Inquiry                     342
# Name: count, dtype: int64
#
# priority
# medium    9753
# high      9149
# low       4845
# Name: count, dtype: int64

# %%
# !ls
# Out:
# drive  sample_data

# %%
from sklearn.model_selection import train_test_split

final_df["stratify_label"] = (
    final_df["queue"] + " | " + final_df["priority"]
)

train_df, temp_df = train_test_split(
    final_df,
    test_size=0.20,
    random_state=42,
    stratify=final_df["stratify_label"]
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.50,
    random_state=42,
    stratify=temp_df["stratify_label"]
)

print("Train:", len(train_df))
print("Validation:", len(val_df))
print("Test:", len(test_df))
# Out:
# Train: 18997
# Validation: 2375
# Test: 2375

# %%
train_df = train_df.drop(columns=["stratify_label"])
val_df = val_df.drop(columns=["stratify_label"])
test_df = test_df.drop(columns=["stratify_label"])

# %%
train_df.to_csv(
    "/content/drive/MyDrive/SupportOpsAI/data/processed/train.csv",
    index=False
)

val_df.to_csv(
    "/content/drive/MyDrive/SupportOpsAI/data/processed/validation.csv",
    index=False
)

test_df.to_csv(
    "/content/drive/MyDrive/SupportOpsAI/data/processed/test.csv",
    index=False
)

print("Saved train/validation/test splits.")
# Out:
# Saved train/validation/test splits.

# %%
def format_ticket(row):
    subject = row["subject"] if row["subject"] else ""
    body = row["body"]

    return {
        "messages": [
            {
                "role": "system",
                "content": (
                    "You are a customer support ticket classifier. "
                    "Classify the ticket and return only valid JSON."
                )
            },
            {
                "role": "user",
                "content": (
                    f"Subject: {subject}\n\n"
                    f"Body: {body}"
                )
            },
            {
                "role": "assistant",
                "content": (
                    f'{{"queue": "{row["queue"]}", '
                    f'"priority": "{row["priority"]}"}}'
                )
            }
        ]
    }

# %%
train_formatted = train_df.apply(format_ticket, axis=1).tolist()
val_formatted = val_df.apply(format_ticket, axis=1).tolist()
test_formatted = test_df.apply(format_ticket, axis=1).tolist()

print("Train examples:", len(train_formatted))
print("Validation examples:", len(val_formatted))
print("Test examples:", len(test_formatted))
# Out:
# Train examples: 18997
# Validation examples: 2375
# Test examples: 2375

# %%
train_formatted[0]
# Out:
# {'messages': [{'role': 'system',
#    'content': 'You are a customer support ticket classifier. Classify the ticket and return only valid JSON.'},
#   {'role': 'user',
#    'content': 'Subject: Inquiry on Jenkins Integration with Our SaaS Platform\n\nBody: Hello, I am contacting you to request information about integrating Jenkins with your project management software. Could you share any documentation or guides you have for this process? I am particularly interested in understanding the benefits and challenges of this integration. I look forward to your response and to discussing this further.'},
#   {'role': 'assistant',
#    'content': '{"queue": "Product Support", "priority": "medium"}'}]}

# %%
from datasets import Dataset

train_dataset = Dataset.from_list(train_formatted)
val_dataset = Dataset.from_list(val_formatted)
test_dataset = Dataset.from_list(test_formatted)

print(train_dataset)
print(val_dataset)
print(test_dataset)
# Out:
# Dataset({
#     features: ['messages'],
#     num_rows: 18997
# })
# Dataset({
#     features: ['messages'],
#     num_rows: 2375
# })
# Dataset({
#     features: ['messages'],
#     num_rows: 2375
# })

# %%
from transformers import AutoTokenizer

model_name = "Qwen/Qwen2.5-1.5B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)

print("Tokenizer loaded")
# Out:
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
#   warnings.warn(f"\nError while fetching `HF_TOKEN` secret value from your vault: '{str(e)}'.")
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# Tokenizer loaded

# %%
print(tokenizer.chat_template)
# Out:
# {%- if tools %}
#     {{- '<|im_start|>system\n' }}
#     {%- if messages[0]['role'] == 'system' %}
#         {{- messages[0]['content'] }}
#     {%- else %}
#         {{- 'You are Qwen, created by Alibaba Cloud. You are a helpful assistant.' }}
#     {%- endif %}
#     {{- "\n\n# Tools\n\nYou may call one or more functions to assist with the user query.\n\nYou are provided with function signatures within <tools></tools> XML tags:\n<tools>" }}
#     {%- for tool in tools %}
#         {{- "\n" }}
#         {{- tool | tojson }}
#     {%- endfor %}
#     {{- "\n</tools>\n\nFor each function call, return a json object with function name and arguments within <tool_call></tool_call> XML tags:\n<tool_call>\n{\"name\": <function-name>, \"arguments\": <args-json-object>}\n</tool_call><|im_end|>\n" }}
# {%- else %}
#     {%- if messages[0]['role'] == 'system' %}
#         {{- '<|im_start|>system\n' + messages[0]['content'] + '<|im_end|>\n' }}
#     {%- else %}
#         {{- '<|im_start|>system\nYou are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>\n' }}
#     {%- endif %}
# {%- endif %}
# {%- for message in messages %}
#     {%- if (message.role == "user") or (message.role == "system" and not loop.first) or (message.role == "assistant" and not message.tool_calls) %}
#         {{- '<|im_start|>' + message.role + '\n' + message.content + '<|im_end|>' + '\n' }}
#     {%- elif message.role == "assistant" %}
#         {{- '<|im_start|>' + message.role }}
#         {%- if message.content %}
#             {{- '\n' + message.content }}
#         {%- endif %}
#         {%- for tool_call in message.tool_calls %}
#             {%- if tool_call.function is defined %}
#                 {%- set tool_call = tool_call.function %}
#             {%- endif %}
#             {{- '\n<tool_call>\n{"name": "' }}
#             {{- tool_call.name }}
#             {{- '", "arguments": ' }}
#             {{- tool_call.arguments | tojson }}
#             {{- '}\n</tool_call>' }}
#         {%- endfor %}
#         {{- '<|im_end|>\n' }}
#     {%- elif message.role == "tool" %}
#         {%- if (loop.index0 == 0) or (messages[loop.index0 - 1].role != "tool") %}
#             {{- '<|im_start|>user' }}
#         {%- endif %}
#         {{- '\n<tool_response>\n' }}
#         {{- message.content }}
#         {{- '\n</tool_response>' }}
#         {%- if loop.last or (messages[loop.index0 + 1].role != "tool") %}
#             {{- '<|im_end|>\n' }}
#         {%- endif %}
#     {%- endif %}
# {%- endfor %}
# {%- if add_generation_prompt %}
#     {{- '<|im_start|>assistant\n' }}
# {%- endif %}

# %%
text = tokenizer.apply_chat_template(
    train_dataset[0]["messages"],
    tokenize=False,
    add_generation_prompt=False
)

print(text)
# Out:
# <|im_start|>system
# You are a customer support ticket classifier. Classify the ticket and return only valid JSON.<|im_end|>
# <|im_start|>user
# Subject: Inquiry on Jenkins Integration with Our SaaS Platform
#
# Body: Hello, I am contacting you to request information about integrating Jenkins with your project management software. Could you share any documentation or guides you have for this process? I am particularly interested in understanding the benefits and challenges of this integration. I look forward to your response and to discussing this further.<|im_end|>
# <|im_start|>assistant
# {"queue": "Product Support", "priority": "medium"}<|im_end|>

# %%
tokens = tokenizer(
    text,
    return_tensors="pt"
)

print(tokens["input_ids"].shape)
# Out:
# torch.Size([1, 117])

# %%
print(tokens["input_ids"][0][:30])
# Out:
# tensor([151644,   8948,    198,   2610,    525,    264,   6002,   1824,  11727,
#          33365,     13,   3228,   1437,    279,  11727,    323,    470,   1172,
#           2697,   4718,     13, 151645,    198, 151644,    872,    198,  13019,
#             25,  65702,    389])

# %%
print(tokenizer.convert_ids_to_tokens(tokens["input_ids"][0][:30]))
# Out:
# ['<|im_start|>', 'system', 'Ċ', 'You', 'Ġare', 'Ġa', 'Ġcustomer', 'Ġsupport', 'Ġticket', 'Ġclassifier', '.', 'ĠClass', 'ify', 'Ġthe', 'Ġticket', 'Ġand', 'Ġreturn', 'Ġonly', 'Ġvalid', 'ĠJSON', '.', '<|im_end|>', 'Ċ', '<|im_start|>', 'user', 'Ċ', 'Subject', ':', 'ĠInquiry', 'Ġon']

# %%
def apply_chat_template(example):
    example["text"] = tokenizer.apply_chat_template(
        example["messages"],
        tokenize=False,
        add_generation_prompt=False
    )
    return example


train_dataset = train_dataset.map(apply_chat_template)
val_dataset = val_dataset.map(apply_chat_template)
test_dataset = test_dataset.map(apply_chat_template)
# Out:
# Map:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2375 [00:00<?, ? examples/s]

# %%
print(train_dataset.column_names)
# Out:
# ['messages', 'text']

# %%
print(train_dataset[0]["text"])
# Out:
# <|im_start|>system
# You are a customer support ticket classifier. Classify the ticket and return only valid JSON.<|im_end|>
# <|im_start|>user
# Subject: Inquiry on Jenkins Integration with Our SaaS Platform
#
# Body: Hello, I am contacting you to request information about integrating Jenkins with your project management software. Could you share any documentation or guides you have for this process? I am particularly interested in understanding the benefits and challenges of this integration. I look forward to your response and to discussing this further.<|im_end|>
# <|im_start|>assistant
# {"queue": "Product Support", "priority": "medium"}<|im_end|>

# %%
token_lengths = [
    len(tokenizer(x["text"])["input_ids"])
    for x in train_dataset
]

print("Min:", min(token_lengths))
print("Max:", max(token_lengths))
print("Average:", sum(token_lengths) / len(token_lengths))
# Out:
# Min: 54
# Max: 370
# Average: 122.63178396588935

# %%
from transformers import AutoModelForCausalLM
import torch

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)
# Out:
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.09GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
print(model.hf_device_map if hasattr(model, "hf_device_map") else "No device map")
# Out:
# No device map

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os

project_path = "/content/drive/MyDrive/SupportOpsAI"

print(os.path.exists(project_path))
print(os.listdir(project_path))
# Out:
# True
# ['data']

# %%
import os

project_path = "/content/drive/MyDrive/SupportOpsAI"
processed_path = f"{project_path}/data/processed"

print("Project exists:", os.path.exists(project_path))
print("Processed data:")
print(os.listdir(processed_path))
# Out:
# Project exists: True
# Processed data:
# ['train.csv', 'validation.csv', 'english_clean.csv', 'test.csv']

# %%
import pandas as pd

processed_path = "/content/drive/MyDrive/SupportOpsAI/data/processed"

train_df = pd.read_csv(f"{processed_path}/train.csv")
val_df = pd.read_csv(f"{processed_path}/validation.csv")
test_df = pd.read_csv(f"{processed_path}/test.csv")

print("Train:", train_df.shape)
print("Validation:", val_df.shape)
print("Test:", test_df.shape)
# Out:
# Train: (18997, 6)
# Validation: (2375, 6)
# Test: (2375, 6)

# %%
from transformers import AutoTokenizer

model_name = "Qwen/Qwen2.5-1.5B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)

print("Tokenizer loaded")
# Out:
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
#   warnings.warn(f"\nError while fetching `HF_TOKEN` secret value from your vault: '{str(e)}'.")
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# Tokenizer loaded

# %%
from datasets import Dataset

def format_ticket(row):
    subject = row["subject"] if pd.notna(row["subject"]) else ""
    body = row["body"]

    return {
        "messages": [
            {
                "role": "system",
                "content": (
                    "You are a customer support ticket classifier. "
                    "Classify the ticket and return only valid JSON."
                )
            },
            {
                "role": "user",
                "content": (
                    f"Subject: {subject}\n\n"
                    f"Body: {body}"
                )
            },
            {
                "role": "assistant",
                "content": (
                    f'{{"queue": "{row["queue"]}", '
                    f'"priority": "{row["priority"]}"}}'
                )
            }
        ]
    }

train_formatted = train_df.apply(format_ticket, axis=1).tolist()
val_formatted = val_df.apply(format_ticket, axis=1).tolist()
test_formatted = test_df.apply(format_ticket, axis=1).tolist()

train_dataset = Dataset.from_list(train_formatted)
val_dataset = Dataset.from_list(val_formatted)
test_dataset = Dataset.from_list(test_formatted)

print(len(train_dataset), len(val_dataset), len(test_dataset))
# Out:
# 18997 2375 2375

# %%
def apply_chat_template(example):
    example["text"] = tokenizer.apply_chat_template(
        example["messages"],
        tokenize=False,
        add_generation_prompt=False
    )
    return example

train_dataset = train_dataset.map(apply_chat_template)
val_dataset = val_dataset.map(apply_chat_template)
test_dataset = test_dataset.map(apply_chat_template)
# Out:
# Map:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2375 [00:00<?, ? examples/s]

# %%
print(train_dataset[0]["text"])
# Out:
# <|im_start|>system
# You are a customer support ticket classifier. Classify the ticket and return only valid JSON.<|im_end|>
# <|im_start|>user
# Subject: Inquiry on Jenkins Integration with Our SaaS Platform
#
# Body: Hello, I am contacting you to request information about integrating Jenkins with your project management software. Could you share any documentation or guides you have for this process? I am particularly interested in understanding the benefits and challenges of this integration. I look forward to your response and to discussing this further.<|im_end|>
# <|im_start|>assistant
# {"queue": "Product Support", "priority": "medium"}<|im_end|>

# %%
import torch
from transformers import AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

print(model.device)
# Out:
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.09GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# cuda:0

# %%
messages = [
    {
        "role": "system",
        "content": (
            "You are a customer support ticket classifier. "
            "Classify the ticket and return only valid JSON."
        )
    },
    {
        "role": "user",
        "content": (
            "Subject: Wireless mouse stopped working\n\n"
            "Body: My wireless mouse suddenly stopped responding. "
            "I replaced the batteries but it still does not work."
        )
    }
]

prompt = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

inputs = tokenizer(
    prompt,
    return_tensors="pt"
).to(model.device)

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=30
    )

generated_tokens = outputs[0][inputs["input_ids"].shape[1]:]

response = tokenizer.decode(
    generated_tokens,
    skip_special_tokens=True
)

print(response)
# Out:
# {
#   "classification": "hardware malfunction"
# }

# %%
import torch

SYSTEM_PROMPT = """You are a customer support ticket classifier.

Choose exactly one queue from:
Technical Support
Product Support
Customer Service
IT Support
Billing and Payments
Returns and Exchanges
Service Outages and Maintenance
Sales and Pre-Sales
Human Resources
General Inquiry

Choose exactly one priority from:
low
medium
high

Return ONLY valid JSON in exactly this format:
{"queue": "<queue>", "priority": "<priority>"}
"""

def predict_ticket(subject, body):
    subject = subject if pd.notna(subject) else ""

    messages = [
        {
            "role": "system",
            "content": SYSTEM_PROMPT
        },
        {
            "role": "user",
            "content": f"Subject: {subject}\n\nBody: {body}"
        }
    ]

    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(
        prompt,
        return_tensors="pt"
    ).to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=30,
            do_sample=False
        )

    generated_tokens = outputs[0][inputs["input_ids"].shape[1]:]

    return tokenizer.decode(
        generated_tokens,
        skip_special_tokens=True
    ).strip()

# %%
import json
import re
import pandas as pd
import torch
from sklearn.metrics import accuracy_score, f1_score
from tqdm.auto import tqdm

# Allowed labels
ALLOWED_QUEUES = {
    "Technical Support",
    "Product Support",
    "Customer Service",
    "IT Support",
    "Billing and Payments",
    "Returns and Exchanges",
    "Service Outages and Maintenance",
    "Sales and Pre-Sales",
    "Human Resources",
    "General Inquiry"
}

ALLOWED_PRIORITIES = {"low", "medium", "high"}

# Make sure tokenizer can pad
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

tokenizer.padding_side = "left"


def parse_prediction(response):
    """
    Extract JSON from model response and validate labels.
    """
    response = response.strip()

    # First try the entire response
    try:
        data = json.loads(response)
    except json.JSONDecodeError:
        # Try extracting a JSON object from surrounding text
        match = re.search(r'\{.*?\}', response, re.DOTALL)

        if not match:
            return None

        try:
            data = json.loads(match.group())
        except json.JSONDecodeError:
            return None

    if not isinstance(data, dict):
        return None

    queue = data.get("queue")
    priority = data.get("priority")

    if queue not in ALLOWED_QUEUES:
        return None

    if priority not in ALLOWED_PRIORITIES:
        return None

    return {
        "queue": queue,
        "priority": priority
    }


def predict_ticket(subject, body):
    subject = subject if pd.notna(subject) else ""

    messages = [
        {
            "role": "system",
            "content": SYSTEM_PROMPT
        },
        {
            "role": "user",
            "content": f"Subject: {subject}\n\nBody: {body}"
        }
    ]

    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(
        prompt,
        return_tensors="pt"
    ).to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=30,
            do_sample=False,
            pad_token_id=tokenizer.pad_token_id
        )

    generated_tokens = outputs[0][inputs["input_ids"].shape[1]:]

    return tokenizer.decode(
        generated_tokens,
        skip_special_tokens=True
    ).strip()


# Run baseline
baseline_results = []

for _, row in tqdm(
    test_df.iterrows(),
    total=len(test_df),
    desc="Running baseline"
):
    raw_output = predict_ticket(
        row["subject"],
        row["body"]
    )

    prediction = parse_prediction(raw_output)

    baseline_results.append({
        "subject": row["subject"],
        "body": row["body"],
        "true_queue": row["queue"],
        "true_priority": row["priority"],
        "raw_output": raw_output,
        "pred_queue": prediction["queue"] if prediction else None,
        "pred_priority": prediction["priority"] if prediction else None,
        "valid_json": prediction is not None
    })

baseline_df = pd.DataFrame(baseline_results)

print("\nBaseline evaluation complete!")
print("Tickets evaluated:", len(baseline_df))
# Out:
# Running baseline:   0%|          | 0/2375 [00:00<?, ?it/s]
# Baseline evaluation complete!
# Tickets evaluated: 2375

# %%
queue_accuracy = accuracy_score(
    baseline_df["true_queue"],
    baseline_df["pred_queue"]
)

queue_f1 = f1_score(
    baseline_df["true_queue"],
    baseline_df["pred_queue"],
    average="macro",
    zero_division=0
)

priority_accuracy = accuracy_score(
    baseline_df["true_priority"],
    baseline_df["pred_priority"]
)

priority_f1 = f1_score(
    baseline_df["true_priority"],
    baseline_df["pred_priority"],
    average="macro",
    zero_division=0
)

joint_accuracy = (
    (baseline_df["true_queue"] == baseline_df["pred_queue"]) &
    (baseline_df["true_priority"] == baseline_df["pred_priority"])
).mean()

json_validity = baseline_df["valid_json"].mean()


print("========== BASELINE RESULTS ==========")
print(f"Queue Accuracy:       {queue_accuracy:.4f}")
print(f"Queue Macro-F1:       {queue_f1:.4f}")
print(f"Priority Accuracy:    {priority_accuracy:.4f}")
print(f"Priority Macro-F1:    {priority_f1:.4f}")
print(f"Joint Accuracy:       {joint_accuracy:.4f}")
print(f"JSON Validity:        {json_validity:.4f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1584/2106820733.py in <cell line: 0>()
# ----> 1 queue_accuracy = accuracy_score(
#       2     baseline_df["true_queue"],
#       3     baseline_df["pred_queue"]
#       4 )
#       5
#
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.13/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     225     # Compute accuracy for each possible representation
#     226     y_true, y_pred = attach_unique(y_true, y_pred)
# --> 227     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     228     check_consistent_length(y_true, y_pred, sample_weight)
#     229
#
# /usr/local/lib/python3.13/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      98     check_consistent_length(y_true, y_pred)
#      99     type_true = type_of_target(y_true, input_name="y_true")
# --> 100     type_pred = type_of_target(y_pred, input_name="y_pred")
#     101
#     102     y_type = {type_true, type_pred}
#
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/multiclass.py in type_of_target(y, input_name, raise_unknown)
#     421     if issparse(first_row_or_val):
#     422         first_row_or_val = first_row_or_val.data
# --> 423     if cached_unique(y).shape[0] > 2 or (y.ndim == 2 and len(first_row_or_val) > 1):
#     424         # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     425         return "multiclass" + suffix
#
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/_unique.py in cached_unique(xp, *ys)
#     103         Unique values of ys.
#     104     """
# --> 105     res = tuple(_cached_unique(y, xp=xp) for y in ys)
#     106     if len(res) == 1:
#     107         return res[0]
#
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/_unique.py in <genexpr>(.0)
#     103         Unique values of ys.
#     104     """
# --> 105     res = tuple(_cached_unique(y, xp=xp) for y in ys)
#     106     if len(res) == 1:
#     107         return res[0]
#
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/_unique.py in _cached_unique(y, xp)
#      76         pass
#      77     xp, _ = get_namespace(y, xp=xp)
# ---> 78     return xp.unique_values(y)
#      79
#      80
#
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/_array_api.py in unique_values(self, x)
#     414
#     415     def unique_values(self, x):
# --> 416         return numpy.unique(x)
#     417
#     418     def unique_all(self, x):
#
# /usr/local/lib/python3.13/dist-packages/numpy/lib/_arraysetops_impl.py in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     289     ar = np.asanyarray(ar)
#     290     if axis is None:
# --> 291         ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     292                         equal_nan=equal_nan, inverse_shape=ar.shape, axis=None)
#     293         return _unpack_tuple(ret)
#
# /usr/local/lib/python3.13/dist-packages/numpy/lib/_arraysetops_impl.py in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan, inverse_shape, axis)
#     356         aux = ar[perm]
#     357     else:
# --> 358         ar.sort()
#     359         aux = ar
#     360     mask = np.empty(aux.shape, dtype=np.bool)
#
# TypeError: '<' not supported between instances of 'NoneType' and 'str'

# %%
# Only evaluate classification metrics on valid predictions
valid_df = baseline_df[baseline_df["valid_json"]].copy()

print("Total tickets:", len(baseline_df))
print("Valid predictions:", len(valid_df))
print("Invalid predictions:", len(baseline_df) - len(valid_df))


# Classification metrics
queue_accuracy = accuracy_score(
    valid_df["true_queue"],
    valid_df["pred_queue"]
)

queue_f1 = f1_score(
    valid_df["true_queue"],
    valid_df["pred_queue"],
    average="macro",
    zero_division=0
)

priority_accuracy = accuracy_score(
    valid_df["true_priority"],
    valid_df["pred_priority"]
)

priority_f1 = f1_score(
    valid_df["true_priority"],
    valid_df["pred_priority"],
    average="macro",
    zero_division=0
)


# Joint accuracy
joint_accuracy = (
    (valid_df["true_queue"] == valid_df["pred_queue"]) &
    (valid_df["true_priority"] == valid_df["pred_priority"])
).mean()


# JSON validity across ALL tickets
json_validity = baseline_df["valid_json"].mean()


print("\n========== BASELINE RESULTS ==========")
print(f"Queue Accuracy:       {queue_accuracy:.4f}")
print(f"Queue Macro-F1:       {queue_f1:.4f}")
print(f"Priority Accuracy:    {priority_accuracy:.4f}")
print(f"Priority Macro-F1:    {priority_f1:.4f}")
print(f"Joint Accuracy:       {joint_accuracy:.4f}")
print(f"JSON Validity:        {json_validity:.4f}")
# Out:
# Total tickets: 2375
# Valid predictions: 2277
# Invalid predictions: 98
#
# ========== BASELINE RESULTS ==========
# Queue Accuracy:       0.3303
# Queue Macro-F1:       0.2040
# Priority Accuracy:    0.3944
# Priority Macro-F1:    0.2375
# Joint Accuracy:       0.1590
# JSON Validity:        0.9587

# %%
strict_joint_accuracy = (
    (baseline_df["true_queue"] == baseline_df["pred_queue"]) &
    (baseline_df["true_priority"] == baseline_df["pred_priority"])
).mean()

print(f"Strict Joint Accuracy: {strict_joint_accuracy:.4f}")
# Out:
# Strict Joint Accuracy: 0.1524

# %%
strict_queue_accuracy = (
    baseline_df["true_queue"] == baseline_df["pred_queue"]
).mean()

strict_priority_accuracy = (
    baseline_df["true_priority"] == baseline_df["pred_priority"]
).mean()

print(f"Strict Queue Accuracy:    {strict_queue_accuracy:.4f}")
print(f"Strict Priority Accuracy: {strict_priority_accuracy:.4f}")
print(f"Strict Joint Accuracy:    {strict_joint_accuracy:.4f}")
# Out:
# Strict Queue Accuracy:    0.3166
# Strict Priority Accuracy: 0.3781
# Strict Joint Accuracy:    0.1524

# %%
import torch
import transformers
import datasets
import peft
import trl
import bitsandbytes

print("Python:", __import__("sys").version)
print("PyTorch:", torch.__version__)
print("CUDA:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

print("\nLibraries:")
print("transformers:", transformers.__version__)
print("datasets:", datasets.__version__)
print("peft:", peft.__version__)
print("trl:", trl.__version__)
print("bitsandbytes:", bitsandbytes.__version__)
# Out:
# Python: 3.13.15 (main, Aug  6 2026, 11:06:22) [GCC 13.3.0]
# PyTorch: 2.11.0+cu128
# CUDA: 12.8
# CUDA available: True
# GPU: Tesla T4
#
# Libraries:
# transformers: 5.16.1
# datasets: 4.8.5
# peft: 0.20.0
# trl: 1.13.0
# bitsandbytes: 0.50.2

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os

PROJECT_DIR = "/content/drive/MyDrive/SupportOpsAI"

print(os.listdir(PROJECT_DIR))
# Out:
# ['data']

# %%
import pandas as pd

processed_path = f"{PROJECT_DIR}/data/processed"

train_df = pd.read_csv(f"{processed_path}/train.csv")
val_df = pd.read_csv(f"{processed_path}/validation.csv")
test_df = pd.read_csv(f"{processed_path}/test.csv")

print("Train:", train_df.shape)
print("Validation:", val_df.shape)
print("Test:", test_df.shape)
# Out:
# Train: (18997, 6)
# Validation: (2375, 6)
# Test: (2375, 6)

# %%
from transformers import AutoTokenizer

model_name = "Qwen/Qwen2.5-1.5B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

tokenizer.padding_side = "right"

print("Tokenizer loaded")
print("Pad token:", tokenizer.pad_token)
# Out:
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
#   warnings.warn(f"\nError while fetching `HF_TOKEN` secret value from your vault: '{str(e)}'.")
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# Tokenizer loaded
# Pad token: <|endoftext|>

# %%
from datasets import Dataset

SYSTEM_PROMPT = """You are a customer support ticket classifier.

Choose exactly one queue from:
Technical Support
Product Support
Customer Service
IT Support
Billing and Payments
Returns and Exchanges
Service Outages and Maintenance
Sales and Pre-Sales
Human Resources
General Inquiry

Choose exactly one priority from:
low
medium
high

Return ONLY valid JSON in exactly this format:
{"queue": "<queue>", "priority": "<priority>"}
"""


def format_ticket(row):
    subject = row["subject"] if pd.notna(row["subject"]) else ""

    return {
        "messages": [
            {
                "role": "system",
                "content": SYSTEM_PROMPT
            },
            {
                "role": "user",
                "content": (
                    f"Subject: {subject}\n\n"
                    f"Body: {row['body']}"
                )
            },
            {
                "role": "assistant",
                "content": (
                    f'{{"queue": "{row["queue"]}", '
                    f'"priority": "{row["priority"]}"}}'
                )
            }
        ]
    }


train_dataset = Dataset.from_list(
    train_df.apply(format_ticket, axis=1).tolist()
)

val_dataset = Dataset.from_list(
    val_df.apply(format_ticket, axis=1).tolist()
)

test_dataset = Dataset.from_list(
    test_df.apply(format_ticket, axis=1).tolist()
)

print(train_dataset)
print(val_dataset)
print(test_dataset)
# Out:
# Dataset({
#     features: ['messages'],
#     num_rows: 18997
# })
# Dataset({
#     features: ['messages'],
#     num_rows: 2375
# })
# Dataset({
#     features: ['messages'],
#     num_rows: 2375
# })

# %%
def apply_chat_template(example):
    example["text"] = tokenizer.apply_chat_template(
        example["messages"],
        tokenize=False,
        add_generation_prompt=False
    )
    return example


train_dataset = train_dataset.map(apply_chat_template)
val_dataset = val_dataset.map(apply_chat_template)
test_dataset = test_dataset.map(apply_chat_template)
# Out:
# Map:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2375 [00:00<?, ? examples/s]

# %%
print(train_dataset[0]["text"])
# Out:
# <|im_start|>system
# You are a customer support ticket classifier.
#
# Choose exactly one queue from:
# Technical Support
# Product Support
# Customer Service
# IT Support
# Billing and Payments
# Returns and Exchanges
# Service Outages and Maintenance
# Sales and Pre-Sales
# Human Resources
# General Inquiry
#
# Choose exactly one priority from:
# low
# medium
# high
#
# Return ONLY valid JSON in exactly this format:
# {"queue": "<queue>", "priority": "<priority>"}
# <|im_end|>
# <|im_start|>user
# Subject: Inquiry on Jenkins Integration with Our SaaS Platform
#
# Body: Hello, I am contacting you to request information about integrating Jenkins with your project management software. Could you share any documentation or guides you have for this process? I am particularly interested in understanding the benefits and challenges of this integration. I look forward to your response and to discussing this further.<|im_end|>
# <|im_start|>assistant
# {"queue": "Product Support", "priority": "medium"}<|im_end|>

# %%
import numpy as np

lengths = []

for example in train_dataset:
    tokens = tokenizer(
        example["text"],
        add_special_tokens=False
    )["input_ids"]

    lengths.append(len(tokens))

print("Min:", min(lengths))
print("Max:", max(lengths))
print("Average:", np.mean(lengths))
# Out:
# Min: 122
# Max: 438
# Average: 191.51250197399588

# %%
import torch

from transformers import (
    AutoModelForCausalLM,
    BitsAndBytesConfig
)


bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
)


model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map="auto",
)

print("QLoRA base model loaded")
print("Device:", model.device)
# Out:
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.09GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# QLoRA base model loaded
# Device: cuda:0

# %%
from peft import prepare_model_for_kbit_training

model = prepare_model_for_kbit_training(
    model,
    use_gradient_checkpointing=True
)

print("Model prepared for k-bit training")
# Out:
# Model prepared for k-bit training

# %%
from peft import LoraConfig, get_peft_model


lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",

    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj"
    ],
)


model = get_peft_model(
    model,
    lora_config
)

model.print_trainable_parameters()
# Out:
# trainable params: 4,358,144 || all params: 1,548,072,448 || trainable%: 0.2815

# %%
print("Model type:", type(model))
print("Trainable parameters:")

model.print_trainable_parameters()
# Out:
# Model type: <class 'peft.peft_model.PeftModelForCausalLM'>
# Trainable parameters:
# trainable params: 4,358,144 || all params: 1,548,072,448 || trainable%: 0.2815

# %%
from trl import SFTTrainer, SFTConfig
import inspect

print(inspect.signature(SFTConfig))
print("\n" + "="*80 + "\n")
print(inspect.signature(SFTTrainer))
# Out:
# (output_dir: str | None = None, per_device_train_batch_size: int = 8, num_train_epochs: float = 3.0, max_steps: int = -1, learning_rate: float = 2e-05, lr_scheduler_type: transformers.trainer_utils.SchedulerType | str = 'linear', lr_scheduler_kwargs: dict | str | None = None, warmup_steps: float = 0, optim: transformers.training_args.OptimizerNames | str = 'adamw_torch_fused', optim_args: str | None = None, weight_decay: float = 0.0, adam_beta1: float = 0.9, adam_beta2: float = 0.999, adam_epsilon: float = 1e-08, optim_target_modules: None | str | list[str] = None, gradient_accumulation_steps: int = 1, average_tokens_across_devices: bool = True, max_grad_norm: float = 1.0, label_smoothing_factor: float = 0.0, bf16: bool | None = None, fp16: bool = False, bf16_full_eval: bool = False, fp16_full_eval: bool = False, tf32: bool | None = None, gradient_checkpointing: bool = True, gradient_checkpointing_kwargs: dict[str, typing.Any] | str | None = None, torch_compile: bool = False, torch_compile_backend: str | None = None, torch_compile_mode: str | None = None, use_liger_kernel: bool = False, liger_kernel_config: dict[str, bool] | None = None, use_cache: bool = False, neftune_noise_alpha: float | None = None, torch_empty_cache_steps: int | None = None, auto_find_batch_size: bool = False, logging_strategy: transformers.trainer_utils.IntervalStrategy | str = 'steps', logging_steps: float = 10, logging_first_step: bool = False, log_on_each_node: bool = True, logging_nan_inf_filter: bool = True, include_num_input_tokens_seen: str | bool = 'no', log_level: str = 'passive', log_level_replica: str = 'warning', disable_tqdm: bool | None = None, report_to: None | str | list[str] = 'none', run_name: str | None = None, project: str = 'huggingface', trackio_space_id: str | None = None, trackio_bucket_id: str | None = None, trackio_static_space_id: Union[str, NoneType, Literal[False]] = None, eval_strategy: transformers.trainer_utils.IntervalStrategy | str = 'no', eval_steps: float | None = None, eval_delay: float = 0, per_device_eval_batch_size: int = 8, prediction_loss_only: bool = False, eval_on_start: bool = False, eval_do_concat_batches: bool = True, eval_use_gather_object: bool = False, eval_accumulation_steps: int | None = None, include_for_metrics: list[str] = <factory>, batch_eval_metrics: bool = False, save_only_model: bool = False, save_strategy: transformers.trainer_utils.SaveStrategy | str = 'steps', save_steps: float = 500, save_on_each_node: bool = False, save_total_limit: int | None = None, enable_jit_checkpoint: bool = False, push_to_hub: bool = False, hub_token: str | None = None, hub_private_repo: bool | None = None, hub_model_id: str | None = None, hub_strategy: transformers.trainer_utils.HubStrategy | str = 'every_save', hub_always_push: bool = False, hub_revision: str | None = None, load_best_model_at_end: bool = False, metric_for_best_model: str | None = None, greater_is_better: bool | None = None, ignore_data_skip: bool = False, restore_callback_states_from_checkpoint: bool = False, full_determinism: bool = False, seed: int = 42, data_seed: int | None = None, use_cpu: bool = False, accelerator_config: dict | str | None = None, parallelism_config: accelerate.parallelism_config.ParallelismConfig | None = None, dataloader_drop_last: bool = False, dataloader_num_workers: int = 0, dataloader_pin_memory: bool = True, dataloader_persistent_workers: bool = False, dataloader_prefetch_factor: int | None = None, dataloader_multiprocessing_context: str | None = None, dataloader_in_order: bool = True, remove_unused_columns: bool = True, label_names: list[str] | None = None, train_sampling_strategy: str = 'random', length_column_name: str = 'length', ddp_find_unused_parameters: bool | None = None, ddp_bucket_cap_mb: int | None = None, ddp_broadcast_buffers: bool | None = None, ddp_static_graph: bool | None = None, ddp_backend: str | None = None, ddp_timeout: int = 1800, fsdp: str | None = None, fsdp_config: dict[str, typing.Any] | str  ...
#
# ================================================================================
#
# (model: 'str | PreTrainedModel | PeftModel', args: trl.trainer.sft_config.SFTConfig | transformers.training_args.TrainingArguments | None = None, data_collator: collections.abc.Callable[[list[typing.Any]], dict[str, typing.Any]] | None = None, train_dataset: datasets.arrow_dataset.Dataset | datasets.iterable_dataset.IterableDataset | None = None, eval_dataset: datasets.arrow_dataset.Dataset | datasets.iterable_dataset.IterableDataset | datasets.dataset_dict.DatasetDict | datasets.dataset_dict.IterableDatasetDict | dict[str, datasets.arrow_dataset.Dataset | datasets.iterable_dataset.IterableDataset] | None = None, processing_class: transformers.tokenization_utils_base.PreTrainedTokenizerBase | transformers.processing_utils.ProcessorMixin | None = None, compute_loss_func: collections.abc.Callable | None = None, compute_metrics: collections.abc.Callable[[transformers.trainer_utils.EvalPrediction], dict] | None = None, callbacks: list[transformers.trainer_callback.TrainerCallback] | None = None, optimizers: tuple[torch.optim.optimizer.Optimizer | None, torch.optim.lr_scheduler.LambdaLR | None] = (None, None), optimizer_cls_and_kwargs: tuple[type[torch.optim.optimizer.Optimizer], dict[str, typing.Any]] | None = None, preprocess_logits_for_metrics: collections.abc.Callable[[torch.Tensor, torch.Tensor], torch.Tensor] | None = None, quantization_config: 'BitsAndBytesConfig | None' = None, peft_config: 'PeftConfig | None' = None, formatting_func: collections.abc.Callable[[dict], str] | None = None)

# %%
print(train_dataset)
print(val_dataset)

print(train_dataset[0]["text"])
# Out:
# Dataset({
#     features: ['messages', 'text'],
#     num_rows: 18997
# })
# Dataset({
#     features: ['messages', 'text'],
#     num_rows: 2375
# })
# <|im_start|>system
# You are a customer support ticket classifier.
#
# Choose exactly one queue from:
# Technical Support
# Product Support
# Customer Service
# IT Support
# Billing and Payments
# Returns and Exchanges
# Service Outages and Maintenance
# Sales and Pre-Sales
# Human Resources
# General Inquiry
#
# Choose exactly one priority from:
# low
# medium
# high
#
# Return ONLY valid JSON in exactly this format:
# {"queue": "<queue>", "priority": "<priority>"}
# <|im_end|>
# <|im_start|>user
# Subject: Inquiry on Jenkins Integration with Our SaaS Platform
#
# Body: Hello, I am contacting you to request information about integrating Jenkins with your project management software. Could you share any documentation or guides you have for this process? I am particularly interested in understanding the benefits and challenges of this integration. I look forward to your response and to discussing this further.<|im_end|>
# <|im_start|>assistant
# {"queue": "Product Support", "priority": "medium"}<|im_end|>

# %%
import gc
import torch

del trainer
del model

gc.collect()
torch.cuda.empty_cache()

print(
    "GPU memory:",
    round(torch.cuda.memory_allocated() / 1e9, 2),
    "GB"
)
# Out:
# GPU memory: 13.93 GB

# %%
from transformers import AutoModelForCausalLM, BitsAndBytesConfig

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]

# %%
from peft import prepare_model_for_kbit_training

model = prepare_model_for_kbit_training(
    model,
    use_gradient_checkpointing=True
)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipykernel_4846/2477220501.py in <cell line: 0>()
#       1 from peft import prepare_model_for_kbit_training
#       2
# ----> 3 model = prepare_model_for_kbit_training(
#       4     model,
#       5     use_gradient_checkpointing=True
#
# /usr/local/lib/python3.13/dist-packages/peft/utils/other.py in prepare_model_for_kbit_training(model, use_gradient_checkpointing, gradient_checkpointing_kwargs, auto_clear_cache)
#     200                 (param.dtype == torch.float16) or (param.dtype == torch.bfloat16)
#     201             ) and param.__class__.__name__ != "Params4bit":
# --> 202                 param.data = param.data.to(torch.float32)
#     203
#     204         # Release CUDA allocator cache after bulk fp16→fp32 casts to reduce
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 892.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 225.81 MiB is free. Including non-PyTorch memory, this process has 14.34 GiB memory in use. Of the allocated memory 14.04 GiB is allocated by PyTorch, and 162.38 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)

# %%
import torch

print("CUDA:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))

x = torch.randn(4096, 4096, device="cuda", dtype=torch.bfloat16)
y = x @ x

torch.cuda.synchronize()

print("GPU test completed")
# Out:
# CUDA: True
# GPU: Tesla T4
# GPU test completed

# %%
del x, y
torch.cuda.empty_cache()

# %%
print(next(model.parameters()).device)
# Out:
# cuda:0

# %%
import gc
import torch

# Clean up current model
del trainer
del model

gc.collect()
torch.cuda.empty_cache()

print("GPU memory cleared")
# Out:
# GPU memory cleared

# %%
from transformers import AutoModelForCausalLM, BitsAndBytesConfig

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]

# %%
from peft import prepare_model_for_kbit_training

model = prepare_model_for_kbit_training(
    model,
    use_gradient_checkpointing=False
)

# %%
from peft import LoraConfig, get_peft_model

lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
    ],
)

model = get_peft_model(model, lora_config)

model.print_trainable_parameters()
# Out:
# trainable params: 4,358,144 || all params: 1,548,072,448 || trainable%: 0.2815

# %%
from trl import SFTConfig

training_args = SFTConfig(
    output_dir=output_dir,

    # Training
    num_train_epochs=3,
    per_device_train_batch_size=8,
    gradient_accumulation_steps=2,

    # Learning rate
    learning_rate=2e-4,
    lr_scheduler_type="cosine",
    warmup_steps=180,

    # T4 -> FP16
    fp16=True,
    bf16=False,

    # Faster training
    gradient_checkpointing=False,
    use_cache=True,

    # Sequence length
    max_length=512,
    packing=False,

    # Train on completion/answer tokens
    completion_only_loss=True,

    # Validation
    eval_strategy="epoch",
    per_device_eval_batch_size=8,

    # Checkpoints
    save_strategy="epoch",
    save_total_limit=2,

    # Best checkpoint
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,

    # Logging
    logging_strategy="steps",
    logging_steps=50,
    report_to="none",

    seed=42,

    dataset_text_field="text",
)

# %%
from trl import SFTTrainer

trainer = SFTTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    processing_class=tokenizer,
)

trainer.model.print_trainable_parameters()
# Out:
# Tokenizing train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Building labels for train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Dropping fully masked examples from train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Building labels for eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Dropping fully masked examples from eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# trainable params: 4,358,144 || all params: 1,548,072,448 || trainable%: 0.2815

# %%
train_loader = trainer.get_train_dataloader()
batch = next(iter(train_loader))

batch = {
    k: v.to(model.device)
    for k, v in batch.items()
    if hasattr(v, "to")
}

torch.cuda.empty_cache()
torch.cuda.synchronize()

import time

start = time.time()

outputs = model(**batch)

torch.cuda.synchronize()

forward_time = time.time() - start

start = time.time()

outputs.loss.backward()

torch.cuda.synchronize()

backward_time = time.time() - start

print("Batch shape:", batch["input_ids"].shape)
print("Forward:", round(forward_time, 2), "sec")
print("Backward:", round(backward_time, 2), "sec")
print("Total:", round(forward_time + backward_time, 2), "sec")
print("GPU memory:", round(torch.cuda.memory_allocated() / 1e9, 2), "GB")
# Out:
# Batch shape: torch.Size([8, 241])
# Forward: 1.02 sec
# Backward: 1.3 sec
# Total: 2.32 sec
# GPU memory: 5.37 GB

# %%
train_result = trainer.train()
# Out:
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipykernel_4846/716956893.py in <cell line: 0>()
# ----> 1 train_result = trainer.train()
#
# /usr/local/lib/python3.13/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1456         ctx = suppress_progress_bars() if args.push_to_hub else contextlib.nullcontext()
#    1457         with ctx:
# -> 1458             return inner_training_loop(
#    1459                 args=args,
#    1460                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.13/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1538         for epoch in range(epochs_trained, num_train_epochs):
#    1539             self.control = self.callback_handler.on_epoch_begin(self.args, self.state, self.control)
# -> 1540             self._run_epoch(
#    1541                 model=model,
#    1542                 epoch=epoch,
#
# /usr/local/lib/python3.13/dist-packages/transformers/trainer.py in _run_epoch(self, model, epoch, train_dataloader, steps_in_epoch, num_update_steps_per_epoch, trial, ignore_keys_for_eval, start_time, resume_from_checkpoint, epochs_trained, steps_trained_in_current_epoch)
#    1766                     sync_context = functools.partial(self.accelerator.no_sync, model=model)
#    1767                 with sync_context():
# -> 1768                     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    1769
#    1770                 if (
#
# /usr/local/lib/python3.13/dist-packages/trl/trainer/sft_trainer.py in training_step(self, *args, **kwargs)
#    1903     def training_step(self, *args, **kwargs):
#    1904         with self.maybe_activation_offload_context:
# -> 1905             return super().training_step(*args, **kwargs)
#    1906
#    1907     def log(self, logs: dict[str, float], start_time: float | None = None) -> None:
#
# /usr/local/lib/python3.13/dist-packages/transformers/trainer.py in training_step(self, model, inputs, num_items_in_batch)
#    1938
#    1939             with self.compute_loss_context_manager():
# -> 1940                 loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    1941
#    1942             del inputs
#
# /usr/local/lib/python3.13/dist-packages/trl/trainer/sft_trainer.py in compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    1801
#    1802         try:
# -> 1803             (loss, outputs) = super().compute_loss(
#    1804                 model, inputs, return_outputs=True, num_items_in_batch=num_items_in_batch
#    1805             )
#
# /usr/local/lib/python3.13/dist-packages/transformers/trainer.py in compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    2012                 kwargs["num_items_in_batch"] = num_items_in_batch
#    2013             inputs = {**inputs, **kwargs}
# -> 2014         outputs = model(**inputs)
#    2015
#    2016         # User-defined compute_loss function
#
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.13/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     941
#     942     def forward(*args, **kwargs):
# --> 943         return model_forward(*args, **kwargs)
#     944
#     945     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.13/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     929
#     930     def __call__(self, *args, **kwargs):
# --> 931         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     932
#     933     def __getstate__(self):
#
# /usr/local/lib/python3.13/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      42     def decorate_autocast(*args, **kwargs):
#      43         with autocast_instance:
# ---> 44             return func(*args, **kwargs)
#      45
#      46     decorate_autocast.__script_unsupported = (  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.13/dist-packages/peft/peft_model.py in forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, task_ids, **kwargs)
#    2099             with self._enable_peft_forward_hooks(**kwargs):
#    2100                 kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 2101                 return self.base_model(
#    2102                     input_ids=input_ids,
#    2103                     attention_mask=attention_mask,
#
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.13/dist-packages/peft/tuners/tuners_utils.py in forward(self, *args, **kwargs)
#     331
#     332     def forward(self, *args: Any, **kwargs: Any):
# --> 333         return self.model.forward(*args, **kwargs)
#     334
#     335     def _pre_injection_hook(self, model: nn.Module, config: PeftConfig, adapter_name: str) -> None:
#
# /usr/local/lib/python3.13/dist-packages/trl/trainer/sft_trainer.py in _chunked_ce_forward(self, input_ids, attention_mask, labels, num_items_in_batch, shift_labels, output_router_logits, **kwargs)
#     327             if lm_head_bias is not None:
#     328                 lm_head_bias = lm_head_bias.full_tensor()
# --> 329         loss, num_correct_tokens, entropy_sum, num_valid_tokens = _chunked_cross_entropy_loss(
#     330             hidden_states,
#     331             lm_head_weight,
#
# /usr/local/lib/python3.13/dist-packages/trl/trainer/sft_trainer.py in _chunked_cross_entropy_loss(hidden_states, lm_head_weight, chunk_size, labels, shift_labels, num_items_in_batch, logit_scale, final_logit_softcapping, lm_head_bias)
#     209         h_chunk = hidden[start : start + chunk_size]
#     210         lbl_chunk = labels[start : start + chunk_size]
# --> 211         chunk_loss, chunk_correct, chunk_entropy = torch.utils.checkpoint.checkpoint(
#     212             _chunk,
#     213             h_chunk,
#
# /usr/local/lib/python3.13/dist-packages/torch/_compile.py in inner(*args, **kwargs)
#      52                 fn.__dynamo_disable = disable_fn  # type: ignore[attr-defined]
#      53
# ---> 54             return disable_fn(*args, **kwargs)
#      55
#      56         return inner
#
# /usr/local/lib/python3.13/dist-packages/torch/_dynamo/eval_frame.py in _fn(*args, **kwargs)
#    1261                         ):
#    1262                             return fn(*args, **kwargs)
# -> 1263                     return fn(*args, **kwargs)
#    1264                 finally:
#    1265                     set_eval_frame(None)
#
# /usr/local/lib/python3.13/dist-packages/torch/utils/checkpoint.py in checkpoint(function, use_reentrant, context_fn, determinism_check, debug, early_stop, *args, **kwargs)
#     510         # Runs pre-forward logic
#     511         next(gen)
# --> 512         ret = function(*args, **kwargs)
#     513         # Runs post-forward logic
#     514         try:
#
# /usr/local/lib/python3.13/dist-packages/trl/trainer/sft_trainer.py in _chunk(h, w, b, lbl, logit_scale, final_logit_softcapping)
#     103         # `transformers`' own `ForCausalLMLoss` do. Matching the weight to the hidden-states dtype keeps the
#     104         # matmul in that dtype, which is what `lm_head`'s own forward computes in.
# --> 105         logits = (h @ w.to(h.dtype).t()).float()
#     106         if b is not None:
#     107             logits = logits + b.float()
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 446.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 217.81 MiB is free. Including non-PyTorch memory, this process has 14.35 GiB memory in use. Of the allocated memory 14.03 GiB is allocated by PyTorch, and 179.00 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)

# %%
from transformers import AutoModelForCausalLM, BitsAndBytesConfig

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]

# %%
from peft import prepare_model_for_kbit_training

model = prepare_model_for_kbit_training(
    model,
    use_gradient_checkpointing=True
)

# %%
from peft import LoraConfig, get_peft_model

lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
    ],
)

model = get_peft_model(model, lora_config)

model.print_trainable_parameters()
# Out:
# trainable params: 4,358,144 || all params: 1,548,072,448 || trainable%: 0.2815

# %%
from trl import SFTConfig

training_args = SFTConfig(
    output_dir=output_dir,

    num_train_epochs=3,

    # Safe for the T4
    per_device_train_batch_size=4,
    gradient_accumulation_steps=4,

    learning_rate=2e-4,
    lr_scheduler_type="cosine",
    warmup_steps=180,

    # T4
    fp16=True,
    bf16=False,

    # Memory saving
    gradient_checkpointing=True,
    use_cache=False,

    max_length=512,
    packing=False,

    completion_only_loss=True,

    eval_strategy="epoch",
    per_device_eval_batch_size=4,

    save_strategy="epoch",
    save_total_limit=2,

    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,

    logging_strategy="steps",
    logging_steps=50,
    report_to="none",

    seed=42,

    dataset_text_field="text",
)

# %%
from trl import SFTTrainer

trainer = SFTTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    processing_class=tokenizer,
)

trainer.model.print_trainable_parameters()
# Out:
# Tokenizing train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Building labels for train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Dropping fully masked examples from train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Building labels for eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Dropping fully masked examples from eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# trainable params: 4,358,144 || all params: 1,548,072,448 || trainable%: 0.2815

# %%
train_loader = trainer.get_train_dataloader()
batch = next(iter(train_loader))

batch = {
    k: v.to(model.device)
    for k, v in batch.items()
    if hasattr(v, "to")
}

torch.cuda.empty_cache()
torch.cuda.synchronize()

import time

start = time.time()

outputs = model(**batch)

torch.cuda.synchronize()

forward_time = time.time() - start

start = time.time()

outputs.loss.backward()

torch.cuda.synchronize()

backward_time = time.time() - start

print("Batch:", batch["input_ids"].shape)
print("Forward:", round(forward_time, 2), "sec")
print("Backward:", round(backward_time, 2), "sec")
print("Total:", round(forward_time + backward_time, 2), "sec")
print("GPU memory:", round(torch.cuda.memory_allocated() / 1e9, 2), "GB")
# Out:
# Batch: torch.Size([4, 241])
# Forward: 0.53 sec
# Backward: 0.76 sec
# Total: 1.29 sec
# GPU memory: 3.53 GB

# %%
training_args = SFTConfig(
    output_dir=output_dir,

    num_train_epochs=3,

    per_device_train_batch_size=8,
    gradient_accumulation_steps=2,

    learning_rate=2e-4,
    lr_scheduler_type="cosine",
    warmup_steps=180,

    fp16=True,
    bf16=False,

    gradient_checkpointing=True,
    use_cache=False,

    max_length=512,
    packing=False,

    completion_only_loss=True,

    eval_strategy="epoch",
    per_device_eval_batch_size=4,

    save_strategy="epoch",
    save_total_limit=2,

    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,

    logging_strategy="steps",
    logging_steps=50,
    report_to="none",

    seed=42,
    dataset_text_field="text",
)

# %%
trainer = SFTTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    processing_class=tokenizer,
)
# Out:
# Tokenizing train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Building labels for train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Dropping fully masked examples from train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Building labels for eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Dropping fully masked examples from eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]

# %%
train_loader = trainer.get_train_dataloader()
batch = next(iter(train_loader))

batch = {
    k: v.to(model.device)
    for k, v in batch.items()
    if hasattr(v, "to")
}

torch.cuda.empty_cache()
torch.cuda.synchronize()

import time

start = time.time()

outputs = model(**batch)

torch.cuda.synchronize()
forward_time = time.time() - start

start = time.time()

outputs.loss.backward()

torch.cuda.synchronize()
backward_time = time.time() - start

print("Batch:", batch["input_ids"].shape)
print("Forward:", round(forward_time, 2), "sec")
print("Backward:", round(backward_time, 2), "sec")
print("Total:", round(forward_time + backward_time, 2), "sec")
print("GPU memory:", round(torch.cuda.memory_allocated() / 1e9, 2), "GB")
# Out:
# Batch: torch.Size([8, 241])
# Forward: 0.87 sec
# Backward: 1.32 sec
# Total: 2.19 sec
# GPU memory: 4.25 GB

# %%
train_result = trainer.train()
# Out:
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipykernel_4846/716956893.py in <cell line: 0>()
# ----> 1 train_result = trainer.train()
#
# /usr/local/lib/python3.13/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1456         ctx = suppress_progress_bars() if args.push_to_hub else contextlib.nullcontext()
#    1457         with ctx:
# -> 1458             return inner_training_loop(
#    1459                 args=args,
#    1460                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.13/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1538         for epoch in range(epochs_trained, num_train_epochs):
#    1539             self.control = self.callback_handler.on_epoch_begin(self.args, self.state, self.control)
# -> 1540             self._run_epoch(
#    1541                 model=model,
#    1542                 epoch=epoch,
#
# /usr/local/lib/python3.13/dist-packages/transformers/trainer.py in _run_epoch(self, model, epoch, train_dataloader, steps_in_epoch, num_update_steps_per_epoch, trial, ignore_keys_for_eval, start_time, resume_from_checkpoint, epochs_trained, steps_trained_in_current_epoch)
#    1788                     grad_norm = None
#    1789                     if self.args.max_grad_norm > 0:
# -> 1790                         grad_norm = self._clip_grad_norm(model)
#    1791                     grad_norm = self._get_grad_norm(model, grad_norm=grad_norm)
#    1792
#
# /usr/local/lib/python3.13/dist-packages/transformers/trainer.py in _clip_grad_norm(self, model)
#    2546         if is_sagemaker_mp_enabled() and self.args.fp16:
#    2547             return self.optimizer.clip_master_grads(self.args.max_grad_norm)
# -> 2548         return self.accelerator.clip_grad_norm_(model.parameters(), self.args.max_grad_norm)
#    2549
#    2550     def _get_grad_norm(self, model, grad_norm=None):
#
# /usr/local/lib/python3.13/dist-packages/accelerate/accelerator.py in clip_grad_norm_(self, parameters, max_norm, norm_type)
#    3004                     if parameters == [p for p in model.parameters()]:
#    3005                         return model.clip_grad_norm_(max_norm, norm_type)
# -> 3006         self.unscale_gradients()
#    3007         return torch.nn.utils.clip_grad_norm_(parameters, max_norm, norm_type=norm_type)
#    3008
#
# /usr/local/lib/python3.13/dist-packages/accelerate/accelerator.py in unscale_gradients(self, optimizer)
#    2942                 while isinstance(opt, AcceleratedOptimizer):
#    2943                     opt = opt.optimizer
# -> 2944                 self.scaler.unscale_(opt)
#    2945
#    2946     def clip_grad_norm_(self, parameters, max_norm, norm_type=2):
#
# /usr/local/lib/python3.13/dist-packages/torch/amp/grad_scaler.py in unscale_(self, optimizer)
#     356         found_inf = torch.full((), 0.0, dtype=torch.float32, device=self._scale.device)
#     357
# --> 358         optimizer_state["found_inf_per_device"] = self._unscale_grads_(
#     359             optimizer, inv_scale, found_inf, False
#     360         )
#
# /usr/local/lib/python3.13/dist-packages/torch/amp/grad_scaler.py in _unscale_grads_(self, optimizer, inv_scale, found_inf, allow_fp16)
#     292             for device, per_dtype_grads in per_device_and_dtype_grads.items():
#     293                 for grads in per_dtype_grads.values():
# --> 294                     torch._amp_foreach_non_finite_check_and_unscale_(
#     295                         grads,
#     296                         per_device_found_inf.get(device),
#
# NotImplementedError: "_amp_foreach_non_finite_check_and_unscale_cuda" not implemented for 'BFloat16'

# %%
for name, param in model.named_parameters():
    if param.requires_grad:
        print(name, param.dtype)
        break
# Out:
# base_model.model.model.layers.0.self_attn.q_proj.lora_A.default.weight torch.bfloat16

# %%
for name, param in model.named_parameters():
    if param.requires_grad:
        param.data = param.data.float()

# %%
from collections import Counter

trainable_dtypes = Counter(
    str(param.dtype)
    for param in model.parameters()
    if param.requires_grad
)

print(trainable_dtypes)
# Out:
# Counter({'torch.float32': 224})

# %%
training_args = SFTConfig(
    output_dir=output_dir,
    num_train_epochs=3,

    per_device_train_batch_size=8,
    gradient_accumulation_steps=2,

    learning_rate=2e-4,
    lr_scheduler_type="cosine",
    warmup_steps=180,

    fp16=False,
    bf16=False,

    gradient_checkpointing=True,
    use_cache=False,

    max_length=512,
    packing=False,

    eval_strategy="epoch",
    per_device_eval_batch_size=4,

    save_strategy="epoch",
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,

    logging_strategy="steps",
    logging_steps=50,
    report_to="none",

    seed=42,
    dataset_text_field="text",
)

# %%
trainer = SFTTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    processing_class=tokenizer,
)
# Out:
# Tokenizing train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Building labels for train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Dropping fully masked examples from train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Building labels for eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Dropping fully masked examples from eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]

# %%
train_result = trainer.train()
# Out:
#     <div>
#
#       <progress value='2569' max='3564' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2569/3564 2:41:45 < 1:02:41, 0.26 it/s, Epoch 2.16/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Entropy</th>
#       <th>Num Tokens</th>
#       <th>Mean Token Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.614572</td>
#       <td>0.600755</td>
#       <td>0.608616</td>
#       <td>3638163.000000</td>
#       <td>0.839367</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.577143</td>
#       <td>0.574452</td>
#       <td>0.597491</td>
#       <td>7276326.000000</td>
#       <td>0.845056</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
output_dir = "/content/drive/MyDrive/SupportOpsAI/models/supportopsai-qlora"

# %%
from transformers.trainer_utils import get_last_checkpoint

last_checkpoint = get_last_checkpoint(output_dir)

print(last_checkpoint)
# Out:
# /content/drive/MyDrive/SupportOpsAI/models/supportopsai-qlora/checkpoint-2376

# %%
model_name = "Qwen/Qwen2.5-1.5B-Instruct"

output_dir = "/content/drive/MyDrive/SupportOpsAI/models/supportopsai-qlora"

print(model_name)
print(output_dir)
# Out:
# Qwen/Qwen2.5-1.5B-Instruct
# /content/drive/MyDrive/SupportOpsAI/models/supportopsai-qlora

# %%
# !pip install -q -U bitsandbytes

# %%
import bitsandbytes as bnb
print(bnb.__version__)
# Out:
# 0.50.2

# %%
model_name = "Qwen/Qwen2.5-1.5B-Instruct"

output_dir = "/content/drive/MyDrive/SupportOpsAI/models/supportopsai-qlora"

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer

model_name = "Qwen/Qwen2.5-1.5B-Instruct"

processed_path = "/content/drive/MyDrive/SupportOpsAI/data/processed"

train_df = pd.read_csv(f"{processed_path}/train.csv")
val_df = pd.read_csv(f"{processed_path}/validation.csv")
test_df = pd.read_csv(f"{processed_path}/test.csv")

tokenizer = AutoTokenizer.from_pretrained(model_name)

print(len(train_df), len(val_df), len(test_df))
# Out:
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# 18997 2375 2375

# %%
SYSTEM_PROMPT = """You are a customer support ticket classifier.

Choose exactly one queue from:
Technical Support
Product Support
Customer Service
IT Support
Billing and Payments
Returns and Exchanges
Service Outages and Maintenance
Sales and Pre-Sales
Human Resources
General Inquiry

Choose exactly one priority from:
low
medium
high

Return ONLY valid JSON in exactly this format:
{"queue": "<queue>", "priority": "<priority>"}
"""

# %%
def format_ticket(row):
    subject = row["subject"] if pd.notna(row["subject"]) else ""

    return {
        "messages": [
            {
                "role": "system",
                "content": SYSTEM_PROMPT
            },
            {
                "role": "user",
                "content": (
                    f"Subject: {subject}\n\n"
                    f"Body: {row['body']}"
                )
            },
            {
                "role": "assistant",
                "content": (
                    f'{{"queue": "{row["queue"]}", '
                    f'"priority": "{row["priority"]}"}}'
                )
            }
        ]
    }

# %%
train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)

train_dataset = train_dataset.map(format_ticket)
val_dataset = val_dataset.map(format_ticket)
# Out:
# Map:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2375 [00:00<?, ? examples/s]

# %%
def apply_chat_template(example):
    example["text"] = tokenizer.apply_chat_template(
        example["messages"],
        tokenize=False,
        add_generation_prompt=False
    )
    return example

train_dataset = train_dataset.map(apply_chat_template)
val_dataset = val_dataset.map(apply_chat_template)
# Out:
# Map:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2375 [00:00<?, ? examples/s]

# %%
import torch
from transformers import AutoModelForCausalLM, BitsAndBytesConfig

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_2346/2526666008.py in <cell line: 0>()
#       9 )
#      10
# ---> 11 model = AutoModelForCausalLM.from_pretrained(
#      12     model_name,
#      13     quantization_config=bnb_config,
#
# /usr/local/lib/python3.13/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     400                 if parent_quant is not None:
#     401                     config.quantization_config = parent_quant
# --> 402             return model_class.from_pretrained(
#     403                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     404             )
#
# /usr/local/lib/python3.13/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, fusion_config, disable_mmap, *model_args, **kwargs)
#    4268             config._experts_implementation = kwargs.pop("experts_implementation")
#    4269
# -> 4270         hf_quantizer, config, device_map = get_hf_quantizer(
#    4271             config, quantization_config, device_map, weights_only, user_agent
#    4272         )
#
# /usr/local/lib/python3.13/dist-packages/transformers/quantizers/auto.py in get_hf_quantizer(config, quantization_config, device_map, weights_only, user_agent)
#     356
#     357     if hf_quantizer is not None:
# --> 358         hf_quantizer.validate_environment(
#     359             device_map=device_map,
#     360             weights_only=weights_only,
#
# /usr/local/lib/python3.13/dist-packages/transformers/quantizers/quantizer_bnb_4bit.py in validate_environment(self, *args, **kwargs)
#      60             )
#      61         if not is_bitsandbytes_available():
# ---> 62             raise ImportError(
#      63                 f"Using `bitsandbytes` 4-bit quantization requires bitsandbytes: `pip install -U bitsandbytes>={BITSANDBYTES_MIN_VERSION}`"
#      64             )
#
# ImportError: Using `bitsandbytes` 4-bit quantization requires bitsandbytes: `pip install -U bitsandbytes>=0.46.1`
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import torch
import transformers
import bitsandbytes as bnb

print("PyTorch:", torch.__version__)
print("Transformers:", transformers.__version__)
print("bitsandbytes:", bnb.__version__)
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_5682/3137894376.py in <cell line: 0>()
#       1 import torch
#       2 import transformers
# ----> 3 import bitsandbytes as bnb
#       4
#       5 print("PyTorch:", torch.__version__)
#
# ModuleNotFoundError: No module named 'bitsandbytes'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install trl
# Out:
# Collecting trl
#   Downloading trl-1.13.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: accelerate>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from trl) (1.14.0)
# Requirement already satisfied: datasets>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from trl) (4.8.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from trl) (3.1.6)
# Requirement already satisfied: packaging>20.0 in /usr/local/lib/python3.13/dist-packages (from trl) (26.3)
# Requirement already satisfied: transformers>=4.56.2 in /usr/local/lib/python3.13/dist-packages (from trl) (5.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.13/dist-packages (from accelerate>=1.4.0->trl) (2.1.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from accelerate>=1.4.0->trl) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from accelerate>=1.4.0->trl) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from accelerate>=1.4.0->trl) (2.11.0+cu128)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from accelerate>=1.4.0->trl) (1.29.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.13/dist-packages (from accelerate>=1.4.0->trl) (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (3.32.5)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (0.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (4.0.1)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (2025.12.0)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.13/dist-packages (from transformers>=4.56.2->trl) (2025.11.3)
# Requirement already satisfied: tokenizers<0.24.0,>=0.23.1 in /usr/local/lib/python3.13/dist-packages (from transformers>=4.56.2->trl) (0.23.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.13/dist-packages (from transformers>=4.56.2->trl) (0.27.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->trl) (3.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (3.14.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets>=4.7.0->trl) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets>=4.7.0->trl) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets>=4.7.0->trl) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets>=4.7.0->trl) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=4.7.0->trl) (0.16.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub>=0.21.0->accelerate>=1.4.0->trl) (8.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub>=0.21.0->accelerate>=1.4.0->trl) (1.6.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub>=0.21.0->accelerate>=1.4.0->trl) (4.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.2->datasets>=4.7.0->trl) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.2->datasets>=4.7.0->trl) (2.5.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.6.1)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.8.90)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets>=4.7.0->trl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets>=4.7.0->trl) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets>=4.7.0->trl) (2026.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers>=4.56.2->trl) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers>=4.56.2->trl) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer->transformers>=4.56.2->trl) (0.0.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (1.24.5)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.0.0->accelerate>=1.4.0->trl) (1.8.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=4.7.0->trl) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers>=4.56.2->trl) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers>=4.56.2->trl) (2.21.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers>=4.56.2->trl) (0.1.2)
# Downloading trl-1.13.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 7.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: trl
# Successfully installed trl-1.13.0

# %%
# ============================================================
# SupportOpsAI — Restore training environment
# Resume from latest QLoRA checkpoint
# ============================================================

import os
import torch
import pandas as pd

from google.colab import drive

# ------------------------------------------------------------
# 1. Mount Google Drive
# ------------------------------------------------------------

drive.mount("/content/drive")

# ------------------------------------------------------------
# 2. Project paths + model
# ------------------------------------------------------------

model_name = "Qwen/Qwen2.5-1.5B-Instruct"

processed_path = "/content/drive/MyDrive/SupportOpsAI/data/processed"
output_dir = "/content/drive/MyDrive/SupportOpsAI/models/supportopsai-qlora"

print("Model:", model_name)
print("Output:", output_dir)

# ------------------------------------------------------------
# 3. Check GPU + library versions
# ------------------------------------------------------------

import transformers
import datasets
import peft
import trl
import bitsandbytes as bnb

print("\nEnvironment:")
print("PyTorch:", torch.__version__)
print("CUDA:", torch.version.cuda)
print("GPU:", torch.cuda.get_device_name(0))
print("Transformers:", transformers.__version__)
print("Datasets:", datasets.__version__)
print("PEFT:", peft.__version__)
print("TRL:", trl.__version__)
print("bitsandbytes:", bnb.__version__)

# ------------------------------------------------------------
# 4. Load datasets
# ------------------------------------------------------------

train_df = pd.read_csv(f"{processed_path}/train.csv")
val_df = pd.read_csv(f"{processed_path}/validation.csv")

print("\nDataset sizes:")
print("Train:", len(train_df))
print("Validation:", len(val_df))

# ------------------------------------------------------------
# 5. Tokenizer
# ------------------------------------------------------------

from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_name)

# ------------------------------------------------------------
# 6. System prompt
# ------------------------------------------------------------

SYSTEM_PROMPT = """You are a customer support ticket classifier.

Choose exactly one queue from:
Technical Support
Product Support
Customer Service
IT Support
Billing and Payments
Returns and Exchanges
Service Outages and Maintenance
Sales and Pre-Sales
Human Resources
General Inquiry

Choose exactly one priority from:
low
medium
high

Return ONLY valid JSON in exactly this format:
{"queue": "<queue>", "priority": "<priority>"}
"""

# ------------------------------------------------------------
# 7. Convert dataframe rows into chat examples
# ------------------------------------------------------------

from datasets import Dataset

def format_ticket(row):
    subject = row["subject"] if pd.notna(row["subject"]) else ""

    return {
        "messages": [
            {
                "role": "system",
                "content": SYSTEM_PROMPT
            },
            {
                "role": "user",
                "content": (
                    f"Subject: {subject}\n\n"
                    f"Body: {row['body']}"
                )
            },
            {
                "role": "assistant",
                "content": (
                    f'{{"queue": "{row["queue"]}", '
                    f'"priority": "{row["priority"]}"}}'
                )
            }
        ]
    }

train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)

train_dataset = train_dataset.map(
    format_ticket,
    remove_columns=train_dataset.column_names
)

val_dataset = val_dataset.map(
    format_ticket,
    remove_columns=val_dataset.column_names
)

# ------------------------------------------------------------
# 8. Apply Qwen chat template
# ------------------------------------------------------------

def apply_chat_template(example):
    example["text"] = tokenizer.apply_chat_template(
        example["messages"],
        tokenize=False,
        add_generation_prompt=False
    )
    return example

train_dataset = train_dataset.map(apply_chat_template)
val_dataset = val_dataset.map(apply_chat_template)

print("\nFormatted datasets:")
print(train_dataset)
print(val_dataset)

# ------------------------------------------------------------
# 9. Load 4-bit QLoRA base model
# ------------------------------------------------------------

from transformers import (
    AutoModelForCausalLM,
    BitsAndBytesConfig
)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    torch_dtype=torch.float16,
    device_map="auto",
)

# ------------------------------------------------------------
# 10. Prepare model for k-bit training
# ------------------------------------------------------------

from peft import prepare_model_for_kbit_training

model = prepare_model_for_kbit_training(
    model,
    use_gradient_checkpointing=True
)

# ------------------------------------------------------------
# 11. LoRA configuration
# ------------------------------------------------------------

from peft import LoraConfig, get_peft_model

lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
    ],
)

model = get_peft_model(model, lora_config)

# ------------------------------------------------------------
# 12. Fix LoRA dtype
#     (Important: prevents the BF16 GradScaler error we hit)
# ------------------------------------------------------------

for name, param in model.named_parameters():
    if param.requires_grad:
        param.data = param.data.float()

# ------------------------------------------------------------
# 13. Verify trainable parameters
# ------------------------------------------------------------

print("\nTrainable parameters:")
model.print_trainable_parameters()

from collections import Counter

trainable_dtypes = Counter(
    str(param.dtype)
    for param in model.parameters()
    if param.requires_grad
)

print("Trainable dtypes:", trainable_dtypes)

# ------------------------------------------------------------
# 14. Find latest checkpoint
# ------------------------------------------------------------

from transformers.trainer_utils import get_last_checkpoint

last_checkpoint = get_last_checkpoint(output_dir)

print("\nLatest checkpoint:")
print(last_checkpoint)

if last_checkpoint is None:
    raise RuntimeError(
        "No checkpoint found! Do NOT start training."
    )

# ------------------------------------------------------------
# 15. Training configuration
# ------------------------------------------------------------

from trl import SFTConfig

training_args = SFTConfig(
    output_dir=output_dir,

    num_train_epochs=3,

    per_device_train_batch_size=8,
    gradient_accumulation_steps=2,

    learning_rate=2e-4,
    lr_scheduler_type="cosine",
    warmup_steps=180,

    # Important: both disabled because FP16 GradScaler
    # caused the BF16 gradient error on the T4.
    fp16=False,
    bf16=False,

    gradient_checkpointing=True,
    use_cache=False,

    max_length=512,
    packing=False,

    eval_strategy="epoch",
    per_device_eval_batch_size=4,

    save_strategy="epoch",
    save_total_limit=2,

    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,

    logging_strategy="steps",
    logging_steps=50,

    report_to="none",
    seed=42,

    dataset_text_field="text",
)

# ------------------------------------------------------------
# 16. Create Trainer
# ------------------------------------------------------------

from trl import SFTTrainer

trainer = SFTTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    processing_class=tokenizer,
)

print("\n================================================")
print("READY TO RESUME")
print("================================================")
print("Checkpoint:", last_checkpoint)
print("Current training steps:", trainer.state.global_step)
print("DO NOT call trainer.train() yet.")
# Out:
# Mounted at /content/drive
# Model: Qwen/Qwen2.5-1.5B-Instruct
# Output: /content/drive/MyDrive/SupportOpsAI/models/supportopsai-qlora
#
# Environment:
# PyTorch: 2.11.0+cu128
# CUDA: 12.8
# GPU: Tesla T4
# Transformers: 5.16.1
# Datasets: 4.8.5
# PEFT: 0.20.0
# TRL: 1.13.0
# bitsandbytes: 0.50.2
#
# Dataset sizes:
# Train: 18997
# Validation: 2375
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
#   warnings.warn(f"\nError while fetching `HF_TOKEN` secret value from your vault: '{str(e)}'.")
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# Map:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Map:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Formatted datasets:
# Dataset({
#     features: ['messages', 'text'],
#     num_rows: 18997
# })
# Dataset({
#     features: ['messages', 'text'],
#     num_rows: 2375
# })
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.09GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Trainable parameters:
# trainable params: 4,358,144 || all params: 1,548,072,448 || trainable%: 0.2815
# Trainable dtypes: Counter({'torch.float32': 224})
#
# Latest checkpoint:
# /content/drive/MyDrive/SupportOpsAI/models/supportopsai-qlora/checkpoint-2376
# Tokenizing train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Building labels for train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Dropping fully masked examples from train dataset:   0%|          | 0/18997 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Building labels for eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Dropping fully masked examples from eval dataset:   0%|          | 0/2375 [00:00<?, ? examples/s]
# ================================================
# READY TO RESUME
# ================================================
# Checkpoint: /content/drive/MyDrive/SupportOpsAI/models/supportopsai-qlora/checkpoint-2376
# Current training steps: 0
# DO NOT call trainer.train() yet.

# %%
train_result = trainer.train(
    resume_from_checkpoint=last_checkpoint
)
# Out:
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
#     <div>
#
#       <progress value='3564' max='3564' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3564/3564 1:37:02, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Entropy</th>
#       <th>Num Tokens</th>
#       <th>Mean Token Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3</td>
#       <td>0.557514</td>
#       <td>0.561491</td>
#       <td>0.551457</td>
#       <td>3638163.000000</td>
#       <td>0.847351</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# Save the final trained LoRA adapter

final_model_path = "/content/drive/MyDrive/SupportOpsAI/models/supportopsai-qlora-final"

trainer.save_model(final_model_path)
tokenizer.save_pretrained(final_model_path)

print("Final adapter saved to:")
print(final_model_path)
# Out:
# Final adapter saved to:
# /content/drive/MyDrive/SupportOpsAI/models/supportopsai-qlora-final

# %%
import os

print(os.listdir(final_model_path))
# Out:
# ['README.md', 'adapter_model.safetensors', 'adapter_config.json', 'chat_template.jinja', 'tokenizer_config.json', 'tokenizer.json', 'training_args.bin']

# %%
# ============================================================
# SUPPORTOPSAI — EVALUATE TRAINED QLORA MODEL
# ============================================================

import json
import re
import torch
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score


# ------------------------------------------------------------
# 1. System prompt
# ------------------------------------------------------------

SYSTEM_PROMPT = """
You are a customer support ticket classification assistant.

Given a customer support ticket, classify it into exactly one queue
and exactly one priority.

Allowed queues:
- Billing and Payments
- Customer Service
- General Inquiry
- Human Resources
- IT Support
- Product Support
- Returns and Exchanges
- Sales and Pre-Sales
- Service Outages and Maintenance
- Technical Support

Allowed priorities:
- low
- medium
- high

Return ONLY valid JSON in exactly this format:

{
  "queue": "queue name",
  "priority": "priority level"
}
"""


VALID_QUEUES = {
    "Billing and Payments",
    "Customer Service",
    "General Inquiry",
    "Human Resources",
    "IT Support",
    "Product Support",
    "Returns and Exchanges",
    "Sales and Pre-Sales",
    "Service Outages and Maintenance",
    "Technical Support",
}

VALID_PRIORITIES = {
    "low",
    "medium",
    "high",
}


# ------------------------------------------------------------
# 2. Prediction function
# ------------------------------------------------------------

def predict_ticket(subject, body):

    subject = "" if pd.isna(subject) else str(subject)
    body = "" if pd.isna(body) else str(body)

    messages = [
        {
            "role": "system",
            "content": SYSTEM_PROMPT
        },
        {
            "role": "user",
            "content": f"Subject: {subject}\n\nBody: {body}"
        }
    ]

    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(
        prompt,
        return_tensors="pt"
    ).to(model.device)

    with torch.no_grad():

        outputs = model.generate(
            **inputs,
            max_new_tokens=30,
            do_sample=False,
            pad_token_id=tokenizer.eos_token_id
        )

    generated_tokens = outputs[0][
        inputs["input_ids"].shape[1]:
    ]

    response = tokenizer.decode(
        generated_tokens,
        skip_special_tokens=True
    ).strip()

    return response


# ------------------------------------------------------------
# 3. Parse model output
# ------------------------------------------------------------

def parse_prediction(response):

    # First try the entire response as JSON
    try:

        obj = json.loads(response)

        queue = obj.get("queue")
        priority = obj.get("priority")

        if (
            queue in VALID_QUEUES
            and priority in VALID_PRIORITIES
        ):
            return queue, priority

    except Exception:
        pass


    # If model added extra text, search for JSON
    match = re.search(
        r'\{.*?"queue".*?"priority".*?\}',
        response,
        re.DOTALL
    )

    if match:

        try:

            obj = json.loads(match.group())

            queue = obj.get("queue")
            priority = obj.get("priority")

            if (
                queue in VALID_QUEUES
                and priority in VALID_PRIORITIES
            ):
                return queue, priority

        except Exception:
            pass


    return None, None


# ------------------------------------------------------------
# 4. Evaluate every test ticket
# ------------------------------------------------------------

pred_queue = []
pred_priority = []
raw_predictions = []

valid_count = 0


for i, row in test_df.iterrows():

    response = predict_ticket(
        row["subject"],
        row["body"]
    )

    queue, priority = parse_prediction(response)

    raw_predictions.append(response)
    pred_queue.append(queue)
    pred_priority.append(priority)

    if queue is not None and priority is not None:
        valid_count += 1

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(test_df)}")


# ------------------------------------------------------------
# 5. Ground truth
# ------------------------------------------------------------

true_queue = test_df["queue"].tolist()
true_priority = test_df["priority"].tolist()


# ------------------------------------------------------------
# 6. Valid prediction metrics
# ------------------------------------------------------------

valid_indices = [
    i
    for i in range(len(test_df))
    if pred_queue[i] is not None
]


valid_true_queue = [
    true_queue[i]
    for i in valid_indices
]

valid_pred_queue = [
    pred_queue[i]
    for i in valid_indices
]

valid_true_priority = [
    true_priority[i]
    for i in valid_indices
]

valid_pred_priority = [
    pred_priority[i]
    for i in valid_indices
]


queue_accuracy = accuracy_score(
    valid_true_queue,
    valid_pred_queue
)

queue_macro_f1 = f1_score(
    valid_true_queue,
    valid_pred_queue,
    average="macro"
)

priority_accuracy = accuracy_score(
    valid_true_priority,
    valid_pred_priority
)

priority_macro_f1 = f1_score(
    valid_true_priority,
    valid_pred_priority,
    average="macro"
)


joint_accuracy = sum(
    pred_queue[i] == true_queue[i]
    and pred_priority[i] == true_priority[i]
    for i in valid_indices
) / len(valid_indices)


json_validity = valid_count / len(test_df)


# ------------------------------------------------------------
# 7. Strict end-to-end metrics
# ------------------------------------------------------------

strict_queue_accuracy = sum(
    pred_queue[i] == true_queue[i]
    for i in range(len(test_df))
) / len(test_df)

strict_priority_accuracy = sum(
    pred_priority[i] == true_priority[i]
    for i in range(len(test_df))
) / len(test_df)

strict_joint_accuracy = sum(
    pred_queue[i] == true_queue[i]
    and pred_priority[i] == true_priority[i]
    for i in range(len(test_df))
) / len(test_df)


# ------------------------------------------------------------
# 8. Display final results
# ------------------------------------------------------------

print("\n" + "=" * 60)
print("SUPPORTOPSAI — QLORA TEST RESULTS")
print("=" * 60)

print(f"\nTotal tickets:       {len(test_df)}")
print(f"Valid predictions:   {valid_count}")
print(f"Invalid predictions: {len(test_df) - valid_count}")

print("\n--- Valid Prediction Metrics ---")

print(f"Queue Accuracy:      {queue_accuracy:.4f}")
print(f"Queue Macro-F1:      {queue_macro_f1:.4f}")

print(f"Priority Accuracy:   {priority_accuracy:.4f}")
print(f"Priority Macro-F1:   {priority_macro_f1:.4f}")

print(f"Joint Accuracy:      {joint_accuracy:.4f}")
print(f"JSON Validity:       {json_validity:.4f}")

print("\n--- Strict End-to-End Metrics ---")

print(f"Strict Queue Acc:    {strict_queue_accuracy:.4f}")
print(f"Strict Priority Acc: {strict_priority_accuracy:.4f}")
print(f"Strict Joint Acc:    {strict_joint_accuracy:.4f}")

print("=" * 60)


# ------------------------------------------------------------
# 9. Save predictions
# ------------------------------------------------------------

results_df = test_df.copy()

results_df["predicted_queue"] = pred_queue
results_df["predicted_priority"] = pred_priority
results_df["raw_prediction"] = raw_predictions

results_path = (
    "/content/drive/MyDrive/SupportOpsAI/"
    "results/qlora_test_predictions.csv"
)

results_df.to_csv(
    results_path,
    index=False
)

print("\nPredictions saved to:")
print(results_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5682/3140486691.py in <cell line: 0>()
#     182
#     183
# --> 184 for i, row in test_df.iterrows():
#     185
#     186     response = predict_ticket(
#
# NameError: name 'test_df' is not defined

# %%
import pandas as pd

test_path = "/content/drive/MyDrive/SupportOpsAI/data/processed/test.csv"

test_df = pd.read_csv(test_path)

print("Test set loaded:", test_df.shape)
print(test_df[["subject", "body", "queue", "priority"]].head())
# Out:
# Test set loaded: (2375, 6)
#                                              subject  \
# 0             Enhancing Squarespace Brand Visibility
# 1                      Access to Medical Information
# 2  Enhancing Security for Medical Data in Hospita...
# 3                                                NaN
# 4                                  Data Breach Event
#
#                                                 body  \
# 0  Looking for detailed guidance on optimizing Sq...
# 1  Dear Customer Support, I am informing you abou...
# 2  Inquiring about securing medical data for hosp...
# 3  I'm encountering incorrect investment forecast...
# 4  A data breach has happened, resulting in the c...
#
#                              queue priority
# 0  Service Outages and Maintenance     high
# 1                Technical Support   medium
# 2             Billing and Payments   medium
# 3                  Product Support     high
# 4                       IT Support     high

# %%
# ============================================================
# SUPPORTOPSAI — EVALUATE TRAINED QLORA MODEL
# ============================================================

import json
import re
import torch
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score


# ------------------------------------------------------------
# 1. System prompt
# ------------------------------------------------------------

SYSTEM_PROMPT = """
You are a customer support ticket classification assistant.

Given a customer support ticket, classify it into exactly one queue
and exactly one priority.

Allowed queues:
- Billing and Payments
- Customer Service
- General Inquiry
- Human Resources
- IT Support
- Product Support
- Returns and Exchanges
- Sales and Pre-Sales
- Service Outages and Maintenance
- Technical Support

Allowed priorities:
- low
- medium
- high

Return ONLY valid JSON in exactly this format:

{
  "queue": "queue name",
  "priority": "priority level"
}
"""


VALID_QUEUES = {
    "Billing and Payments",
    "Customer Service",
    "General Inquiry",
    "Human Resources",
    "IT Support",
    "Product Support",
    "Returns and Exchanges",
    "Sales and Pre-Sales",
    "Service Outages and Maintenance",
    "Technical Support",
}

VALID_PRIORITIES = {
    "low",
    "medium",
    "high",
}


# ------------------------------------------------------------
# 2. Prediction function
# ------------------------------------------------------------

def predict_ticket(subject, body):

    subject = "" if pd.isna(subject) else str(subject)
    body = "" if pd.isna(body) else str(body)

    messages = [
        {
            "role": "system",
            "content": SYSTEM_PROMPT
        },
        {
            "role": "user",
            "content": f"Subject: {subject}\n\nBody: {body}"
        }
    ]

    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(
        prompt,
        return_tensors="pt"
    ).to(model.device)

    with torch.no_grad():

        outputs = model.generate(
            **inputs,
            max_new_tokens=30,
            do_sample=False,
            pad_token_id=tokenizer.eos_token_id
        )

    generated_tokens = outputs[0][
        inputs["input_ids"].shape[1]:
    ]

    response = tokenizer.decode(
        generated_tokens,
        skip_special_tokens=True
    ).strip()

    return response


# ------------------------------------------------------------
# 3. Parse model output
# ------------------------------------------------------------

def parse_prediction(response):

    # First try the entire response as JSON
    try:

        obj = json.loads(response)

        queue = obj.get("queue")
        priority = obj.get("priority")

        if (
            queue in VALID_QUEUES
            and priority in VALID_PRIORITIES
        ):
            return queue, priority

    except Exception:
        pass


    # If model added extra text, search for JSON
    match = re.search(
        r'\{.*?"queue".*?"priority".*?\}',
        response,
        re.DOTALL
    )

    if match:

        try:

            obj = json.loads(match.group())

            queue = obj.get("queue")
            priority = obj.get("priority")

            if (
                queue in VALID_QUEUES
                and priority in VALID_PRIORITIES
            ):
                return queue, priority

        except Exception:
            pass


    return None, None


# ------------------------------------------------------------
# 4. Evaluate every test ticket
# ------------------------------------------------------------

pred_queue = []
pred_priority = []
raw_predictions = []

valid_count = 0


for i, row in test_df.iterrows():

    response = predict_ticket(
        row["subject"],
        row["body"]
    )

    queue, priority = parse_prediction(response)

    raw_predictions.append(response)
    pred_queue.append(queue)
    pred_priority.append(priority)

    if queue is not None and priority is not None:
        valid_count += 1

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(test_df)}")


# ------------------------------------------------------------
# 5. Ground truth
# ------------------------------------------------------------

true_queue = test_df["queue"].tolist()
true_priority = test_df["priority"].tolist()


# ------------------------------------------------------------
# 6. Valid prediction metrics
# ------------------------------------------------------------

valid_indices = [
    i
    for i in range(len(test_df))
    if pred_queue[i] is not None
]


valid_true_queue = [
    true_queue[i]
    for i in valid_indices
]

valid_pred_queue = [
    pred_queue[i]
    for i in valid_indices
]

valid_true_priority = [
    true_priority[i]
    for i in valid_indices
]

valid_pred_priority = [
    pred_priority[i]
    for i in valid_indices
]


queue_accuracy = accuracy_score(
    valid_true_queue,
    valid_pred_queue
)

queue_macro_f1 = f1_score(
    valid_true_queue,
    valid_pred_queue,
    average="macro"
)

priority_accuracy = accuracy_score(
    valid_true_priority,
    valid_pred_priority
)

priority_macro_f1 = f1_score(
    valid_true_priority,
    valid_pred_priority,
    average="macro"
)


joint_accuracy = sum(
    pred_queue[i] == true_queue[i]
    and pred_priority[i] == true_priority[i]
    for i in valid_indices
) / len(valid_indices)


json_validity = valid_count / len(test_df)


# ------------------------------------------------------------
# 7. Strict end-to-end metrics
# ------------------------------------------------------------

strict_queue_accuracy = sum(
    pred_queue[i] == true_queue[i]
    for i in range(len(test_df))
) / len(test_df)

strict_priority_accuracy = sum(
    pred_priority[i] == true_priority[i]
    for i in range(len(test_df))
) / len(test_df)

strict_joint_accuracy = sum(
    pred_queue[i] == true_queue[i]
    and pred_priority[i] == true_priority[i]
    for i in range(len(test_df))
) / len(test_df)


# ------------------------------------------------------------
# 8. Display final results
# ------------------------------------------------------------

print("\n" + "=" * 60)
print("SUPPORTOPSAI — QLORA TEST RESULTS")
print("=" * 60)

print(f"\nTotal tickets:       {len(test_df)}")
print(f"Valid predictions:   {valid_count}")
print(f"Invalid predictions: {len(test_df) - valid_count}")

print("\n--- Valid Prediction Metrics ---")

print(f"Queue Accuracy:      {queue_accuracy:.4f}")
print(f"Queue Macro-F1:      {queue_macro_f1:.4f}")

print(f"Priority Accuracy:   {priority_accuracy:.4f}")
print(f"Priority Macro-F1:   {priority_macro_f1:.4f}")

print(f"Joint Accuracy:      {joint_accuracy:.4f}")
print(f"JSON Validity:       {json_validity:.4f}")

print("\n--- Strict End-to-End Metrics ---")

print(f"Strict Queue Acc:    {strict_queue_accuracy:.4f}")
print(f"Strict Priority Acc: {strict_priority_accuracy:.4f}")
print(f"Strict Joint Acc:    {strict_joint_accuracy:.4f}")

print("=" * 60)


# ------------------------------------------------------------
# 9. Save predictions
# ------------------------------------------------------------

results_df = test_df.copy()

results_df["predicted_queue"] = pred_queue
results_df["predicted_priority"] = pred_priority
results_df["raw_prediction"] = raw_predictions

results_path = (
    "/content/drive/MyDrive/SupportOpsAI/"
    "results/qlora_test_predictions.csv"
)

results_df.to_csv(
    results_path,
    index=False
)

print("\nPredictions saved to:")
print(results_path)
# Out:
# Processed 100/2375
# Processed 200/2375
# Processed 300/2375
# Processed 400/2375
# Processed 500/2375
# Processed 600/2375
# Processed 700/2375
# Processed 800/2375
# Processed 900/2375
# Processed 1000/2375
# Processed 1100/2375
# Processed 1200/2375
# Processed 1300/2375
# Processed 1400/2375
# Processed 1500/2375
# Processed 1600/2375
# Processed 1700/2375
# Processed 1800/2375
# Processed 1900/2375
# Processed 2000/2375
# Processed 2100/2375
# Processed 2200/2375
# Processed 2300/2375
#
# ============================================================
# SUPPORTOPSAI — QLORA TEST RESULTS
# ============================================================
#
# Total tickets:       2375
# Valid predictions:   941
# Invalid predictions: 1434
#
# --- Valid Prediction Metrics ---
# Queue Accuracy:      0.3974
# Queue Macro-F1:      0.1880
# Priority Accuracy:   0.4761
# Priority Macro-F1:   0.3569
# Joint Accuracy:      0.2253
# JSON Validity:       0.3962
#
# --- Strict End-to-End Metrics ---
# Strict Queue Acc:    0.1575
# Strict Priority Acc: 0.1886
# Strict Joint Acc:    0.0893
# ============================================================
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_5682/3140486691.py in <cell line: 0>()
#     343 )
#     344
# --> 345 results_df.to_csv(
#     346     results_path,
#     347     index=False
#
# /usr/local/lib/python3.13/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3965         )
#    3966
# -> 3967         return DataFrameRenderer(formatter).to_csv(
#    3968             path_or_buf,
#    3969             lineterminator=lineterminator,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/formats/csvs.py in save(self)
#     249         """
#     250         # apply compression and byte/text conversion
# --> 251         with get_handle(
#     252             self.filepath_or_buffer,
#     253             self.mode,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747     # Only for write methods
#     748     if "r" not in mode and is_path:
# --> 749         check_parent_directory(str(handle))
#     750
#     751     if compression:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in check_parent_directory(path)
#     614     parent = Path(path).parent
#     615     if not parent.is_dir():
# --> 616         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     617
#     618
#
# OSError: Cannot save file into a non-existent directory: '/content/drive/MyDrive/SupportOpsAI/results'

# %%
import os

results_dir = "/content/drive/MyDrive/SupportOpsAI/results"
os.makedirs(results_dir, exist_ok=True)

results_path = f"{results_dir}/qlora_test_predictions.csv"

results_df = test_df.copy()
results_df["predicted_queue"] = pred_queue
results_df["predicted_priority"] = pred_priority
results_df["raw_prediction"] = raw_predictions

results_df.to_csv(results_path, index=False)

print("Saved:", results_path)
# Out:
# Saved: /content/drive/MyDrive/SupportOpsAI/results/qlora_test_predictions.csv

# %%
for i in range(20):
    print(f"\n--- Example {i+1} ---")
    print("RAW:", repr(raw_predictions[i]))
    print("TRUE:", true_queue[i], "|", true_priority[i])
    print("PARSED:", pred_queue[i], "|", pred_priority[i])
# Out:
# --- Example 1 ---
# RAW: '{\n  "queue": "Customer Service",\n  "priority": "medium"'
# TRUE: Service Outages and Maintenance | high
# PARSED: None | None
#
# --- Example 2 ---
# RAW: '{\n  "queue": "Technical Support",\n  "priority": "high"'
# TRUE: Technical Support | medium
# PARSED: None | None
#
# --- Example 3 ---
# RAW: '{"queue": "Technical Support", "priority": "high"}'
# TRUE: Billing and Payments | medium
# PARSED: Technical Support | high
#
# --- Example 4 ---
# RAW: '{"queue": "Technical Support", "priority": "high"}'
# TRUE: Product Support | high
# PARSED: Technical Support | high
#
# --- Example 5 ---
# RAW: '{"queue": "Technical Support", "priority": "high"}'
# TRUE: IT Support | high
# PARSED: Technical Support | high
#
# --- Example 6 ---
# RAW: '{"queue": "Technical Support", "priority": "high"}'
# TRUE: Technical Support | high
# PARSED: Technical Support | high
#
# --- Example 7 ---
# RAW: '{\n  "queue": "Technical Support",\n  "priority": "medium"'
# TRUE: Technical Support | medium
# PARSED: None | None
#
# --- Example 8 ---
# RAW: '{"queue": "Technical Support", "priority": "high"}'
# TRUE: Product Support | medium
# PARSED: Technical Support | high
#
# --- Example 9 ---
# RAW: '{"queue": "Customer Service", "priority": "medium"}'
# TRUE: Technical Support | medium
# PARSED: Customer Service | medium
#
# --- Example 10 ---
# RAW: '{\n  "queue": "Customer Service",\n  "priority": "medium"'
# TRUE: Technical Support | high
# PARSED: None | None
#
# --- Example 11 ---
# RAW: '{\n  "queue": "Technical Support",\n  "priority": "medium"'
# TRUE: IT Support | high
# PARSED: None | None
#
# --- Example 12 ---
# RAW: '{\n  "queue": "Technical Support",\n  "priority": "medium"'
# TRUE: Product Support | medium
# PARSED: None | None
#
# --- Example 13 ---
# RAW: '{"queue": "Customer Service", "priority": "medium"}'
# TRUE: IT Support | high
# PARSED: Customer Service | medium
#
# --- Example 14 ---
# RAW: '{\n  "queue": "Customer Service",\n  "priority": "medium"'
# TRUE: Product Support | medium
# PARSED: None | None
#
# --- Example 15 ---
# RAW: '{\n  "queue": "Technical Support",\n  "priority": "high"'
# TRUE: Technical Support | medium
# PARSED: None | None
#
# --- Example 16 ---
# RAW: '{\n  "queue": "Technical Support",\n  "priority": "medium"'
# TRUE: IT Support | medium
# PARSED: None | None
#
# --- Example 17 ---
# RAW: '{\n  "queue": "Customer Service",\n  "priority": "medium"'
# TRUE: Product Support | medium
# PARSED: None | None
#
# --- Example 18 ---
# RAW: '{\n  "queue": "Customer Service",\n  "priority": "medium"'
# TRUE: Customer Service | low
# PARSED: None | None
#
# --- Example 19 ---
# RAW: '{\n  "queue": "Customer Service", "priority": "medium"'
# TRUE: Product Support | high
# PARSED: None | None
#
# --- Example 20 ---
# RAW: '{"queue": "Technical Support", "priority": "high"}'
# TRUE: Product Support | high
# PARSED: Technical Support | high

# %%
# !pip install bitsandbytes trl
# Out:
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.13/dist-packages (0.50.2)
# Requirement already satisfied: trl in /usr/local/lib/python3.13/dist-packages (1.13.0)
# Requirement already satisfied: torch<3,>=2.4 in /usr/local/lib/python3.13/dist-packages (from bitsandbytes) (2.11.0+cu128)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.13/dist-packages (from bitsandbytes) (2.1.3)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.13/dist-packages (from bitsandbytes) (26.3)
# Requirement already satisfied: accelerate>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from trl) (1.14.0)
# Requirement already satisfied: datasets>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from trl) (4.8.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from trl) (3.1.6)
# Requirement already satisfied: transformers>=4.56.2 in /usr/local/lib/python3.13/dist-packages (from trl) (5.16.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from accelerate>=1.4.0->trl) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from accelerate>=1.4.0->trl) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from accelerate>=1.4.0->trl) (1.29.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.13/dist-packages (from accelerate>=1.4.0->trl) (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (3.32.5)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (0.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (4.0.1)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.13/dist-packages (from datasets>=4.7.0->trl) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (2025.12.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes) (3.6.1)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.4->bitsandbytes) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.4->bitsandbytes) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.4->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.4->bitsandbytes) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.4->bitsandbytes) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.4->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.4->bitsandbytes) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.4->bitsandbytes) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.4->bitsandbytes) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.4->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.4->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3,>=2.4->bitsandbytes) (12.8.90)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.13/dist-packages (from transformers>=4.56.2->trl) (2025.11.3)
# Requirement already satisfied: tokenizers<0.24.0,>=0.23.1 in /usr/local/lib/python3.13/dist-packages (from transformers>=4.56.2->trl) (0.23.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.13/dist-packages (from transformers>=4.56.2->trl) (0.27.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->trl) (3.0.3)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch<3,>=2.4->bitsandbytes) (1.8.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (3.14.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets>=4.7.0->trl) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets>=4.7.0->trl) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets>=4.7.0->trl) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets>=4.7.0->trl) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=4.7.0->trl) (0.16.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub>=0.21.0->accelerate>=1.4.0->trl) (8.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub>=0.21.0->accelerate>=1.4.0->trl) (1.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.2->datasets>=4.7.0->trl) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.2->datasets>=4.7.0->trl) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch<3,>=2.4->bitsandbytes) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets>=4.7.0->trl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets>=4.7.0->trl) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets>=4.7.0->trl) (2026.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers>=4.56.2->trl) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers>=4.56.2->trl) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer->transformers>=4.56.2->trl) (0.0.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (1.24.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=4.7.0->trl) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers>=4.56.2->trl) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers>=4.56.2->trl) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers>=4.56.2->trl) (0.1.2)

# %%
import torch
import transformers
import datasets
import peft
import trl
import bitsandbytes

print("Python / environment check")
print("-" * 40)

print("Transformers:", transformers.__version__)
print("Datasets:", datasets.__version__)
print("PEFT:", peft.__version__)
print("TRL:", trl.__version__)
print("bitsandbytes:", bitsandbytes.__version__)

print("\nPyTorch:", torch.__version__)
print("CUDA:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("GPU memory:",
          round(torch.cuda.get_device_properties(0).total_memory / 1024**3, 2),
          "GB")
# Out:
# Python / environment check
# ----------------------------------------
# Transformers: 5.16.1
# Datasets: 4.8.5
# PEFT: 0.20.0
# TRL: 1.13.0
# bitsandbytes: 0.50.2
#
# PyTorch: 2.11.0+cu128
# CUDA: 12.8
# CUDA available: True
# GPU: Tesla T4
# GPU memory: 14.56 GB

# %%
# !fusermount -u /content/drive
# !rm -rf /content/drive
# Out:
# fusermount: failed to unmount /content/drive: Invalid argument

# %%
from google.colab import drive

drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import json
import torch
import pandas as pd

from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig
)
from peft import PeftModel
from sklearn.metrics import accuracy_score, f1_score


# ============================================================
# 1. Paths
# ============================================================

base_model_name = "Qwen/Qwen2.5-1.5B-Instruct"

project_path = "/content/drive/MyDrive/SupportOpsAI"
model_path = f"{project_path}/models/supportopsai-qlora-final"
test_path = f"{project_path}/data/processed/test.csv"
results_dir = f"{project_path}/results"

os.makedirs(results_dir, exist_ok=True)


# ============================================================
# 2. Mount Google Drive
# ============================================================

from google.colab import drive

if not os.path.exists("/content/drive/MyDrive"):
    drive.mount("/content/drive")

print("Drive ready.")


# ============================================================
# 3. Check that the trained adapter exists
# ============================================================

print("\nModel directory:")
print(model_path)

if not os.path.exists(model_path):
    raise FileNotFoundError(
        f"\nCould not find:\n{model_path}\n\n"
        "Check whether the final adapter was saved there."
    )

print("\nFiles in model directory:")
print(os.listdir(model_path))


# ============================================================
# 4. Load tokenizer
# ============================================================

tokenizer = AutoTokenizer.from_pretrained(model_path)

print("\nTokenizer loaded.")


# ============================================================
# 5. Load the base Qwen model in 4-bit
# ============================================================

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16,
)

base_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=bnb_config,
    torch_dtype=torch.float16,
    device_map="auto",
)

print("Base model loaded.")


# ============================================================
# 6. Load our trained LoRA adapter
# ============================================================

model = PeftModel.from_pretrained(
    base_model,
    model_path,
)

model.eval()

print("LoRA adapter loaded.")
print("Model ready for evaluation.")


# ============================================================
# 7. Load untouched test set
# ============================================================

test_df = pd.read_csv(test_path)

print("\nTest set:")
print("Rows:", len(test_df))
print(test_df[["queue", "priority"]].head())


# ============================================================
# 8. Prompt
# ============================================================

SYSTEM_PROMPT = """You are a customer support ticket classification assistant.

Given a support ticket, classify it into exactly one queue and exactly one priority.

Allowed queues:
- Technical Support
- Product Support
- Customer Service
- IT Support
- Billing and Payments
- Returns and Exchanges
- Service Outages and Maintenance
- Sales and Pre-Sales
- Human Resources
- General Inquiry

Allowed priorities:
- low
- medium
- high

Return ONLY valid JSON in exactly this format:
{"queue": "<queue>", "priority": "<priority>"}
"""


# ============================================================
# 9. Prediction function
# ============================================================

def predict_ticket(subject, body):

    subject = subject if pd.notna(subject) else ""
    body = body if pd.notna(body) else ""

    messages = [
        {
            "role": "system",
            "content": SYSTEM_PROMPT
        },
        {
            "role": "user",
            "content": f"Subject: {subject}\n\nBody: {body}"
        }
    ]

    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(
        prompt,
        return_tensors="pt"
    ).to(model.device)

    with torch.no_grad():

        outputs = model.generate(
            **inputs,

            # IMPORTANT:
            # Previous evaluation used 30 and many outputs
            # were truncated just before the final "}".
            max_new_tokens=50,

            do_sample=False,

            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.eos_token_id,
        )

    generated_tokens = outputs[0][inputs["input_ids"].shape[1]:]

    return tokenizer.decode(
        generated_tokens,
        skip_special_tokens=True
    ).strip()


# ============================================================
# 10. Parse prediction
# ============================================================

def parse_prediction(raw):

    try:
        prediction = json.loads(raw)

        if not isinstance(prediction, dict):
            return None

        if "queue" not in prediction or "priority" not in prediction:
            return None

        return prediction

    except Exception:
        return None


# ============================================================
# 11. Evaluate entire test set
# ============================================================

predictions = []

print("\nStarting evaluation...")
print(f"Total tickets: {len(test_df)}")
print("This may take a while on the T4.\n")

for i, row in test_df.iterrows():

    raw_output = predict_ticket(
        row["subject"],
        row["body"]
    )

    parsed = parse_prediction(raw_output)

    predictions.append({
        "index": i,
        "subject": row["subject"],
        "body": row["body"],
        "true_queue": row["queue"],
        "true_priority": row["priority"],
        "raw_output": raw_output,
        "predicted_queue": (
            parsed["queue"] if parsed else None
        ),
        "predicted_priority": (
            parsed["priority"] if parsed else None
        ),
        "valid_json": parsed is not None,
    })

    if (i + 1) % 100 == 0:
        print(f"Evaluated {i + 1}/{len(test_df)}")


pred_df = pd.DataFrame(predictions)


# ============================================================
# 12. Calculate metrics
# ============================================================

total = len(pred_df)

valid_mask = pred_df["valid_json"]

valid_df = pred_df[valid_mask].copy()

valid_count = len(valid_df)
invalid_count = total - valid_count


# ---- Valid prediction metrics ----

if valid_count > 0:

    queue_accuracy = accuracy_score(
        valid_df["true_queue"],
        valid_df["predicted_queue"]
    )

    queue_macro_f1 = f1_score(
        valid_df["true_queue"],
        valid_df["predicted_queue"],
        average="macro"
    )

    priority_accuracy = accuracy_score(
        valid_df["true_priority"],
        valid_df["predicted_priority"]
    )

    priority_macro_f1 = f1_score(
        valid_df["true_priority"],
        valid_df["predicted_priority"],
        average="macro"
    )

    joint_accuracy = (
        (valid_df["true_queue"] == valid_df["predicted_queue"]) &
        (valid_df["true_priority"] == valid_df["predicted_priority"])
    ).mean()

else:

    queue_accuracy = 0
    queue_macro_f1 = 0
    priority_accuracy = 0
    priority_macro_f1 = 0
    joint_accuracy = 0


# ---- JSON validity ----

json_validity = valid_count / total


# ---- Strict end-to-end metrics ----
# Invalid JSON counts as incorrect.

strict_queue_accuracy = (
    (pred_df["true_queue"] == pred_df["predicted_queue"]) &
    pred_df["valid_json"]
).mean()

strict_priority_accuracy = (
    (pred_df["true_priority"] == pred_df["predicted_priority"]) &
    pred_df["valid_json"]
).mean()

strict_joint_accuracy = (
    (pred_df["true_queue"] == pred_df["predicted_queue"]) &
    (pred_df["true_priority"] == pred_df["predicted_priority"]) &
    pred_df["valid_json"]
).mean()


# ============================================================
# 13. Print final results
# ============================================================

print("\n" + "=" * 60)
print("FINAL QLoRA EVALUATION")
print("=" * 60)

print(f"\nTotal tickets:       {total}")
print(f"Valid predictions:   {valid_count}")
print(f"Invalid predictions: {invalid_count}")

print("\n--- Valid Prediction Metrics ---")

print(f"Queue Accuracy:      {queue_accuracy:.4f}")
print(f"Queue Macro-F1:      {queue_macro_f1:.4f}")

print(f"Priority Accuracy:   {priority_accuracy:.4f}")
print(f"Priority Macro-F1:   {priority_macro_f1:.4f}")

print(f"Joint Accuracy:      {joint_accuracy:.4f}")

print(f"JSON Validity:       {json_validity:.4f}")

print("\n--- Strict End-to-End Metrics ---")

print(f"Strict Queue Acc:    {strict_queue_accuracy:.4f}")
print(f"Strict Priority Acc: {strict_priority_accuracy:.4f}")
print(f"Strict Joint Acc:    {strict_joint_accuracy:.4f}")


# ============================================================
# 14. Save predictions + metrics
# ============================================================

predictions_path = f"{results_dir}/qlora_test_predictions.csv"

pred_df.to_csv(
    predictions_path,
    index=False
)

metrics = {
    "total_tickets": total,
    "valid_predictions": valid_count,
    "invalid_predictions": invalid_count,

    "queue_accuracy_valid": queue_accuracy,
    "queue_macro_f1_valid": queue_macro_f1,

    "priority_accuracy_valid": priority_accuracy,
    "priority_macro_f1_valid": priority_macro_f1,

    "joint_accuracy_valid": joint_accuracy,

    "json_validity": json_validity,

    "strict_queue_accuracy": strict_queue_accuracy,
    "strict_priority_accuracy": strict_priority_accuracy,
    "strict_joint_accuracy": strict_joint_accuracy,
}

metrics_path = f"{results_dir}/qlora_metrics.json"

with open(metrics_path, "w") as f:
    json.dump(metrics, f, indent=2)

print("\nSaved:")
print(predictions_path)
print(metrics_path)


# ============================================================
# 15. Show examples
# ============================================================

print("\n" + "=" * 60)
print("SAMPLE PREDICTIONS")
print("=" * 60)

for _, row in pred_df.head(10).iterrows():

    print("\nTrue:")
    print({
        "queue": row["true_queue"],
        "priority": row["true_priority"]
    })

    print("Model:")
    print(row["raw_output"])
# Out:
# Drive ready.
#
# Model directory:
# /content/drive/MyDrive/SupportOpsAI/models/supportopsai-qlora-final
#
# Files in model directory:
# ['adapter_config.json', 'README.md', 'adapter_model.safetensors', 'chat_template.jinja', 'tokenizer_config.json', 'training_args.bin', 'tokenizer.json']
#
# Tokenizer loaded.
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
#   warnings.warn(f"\nError while fetching `HF_TOKEN` secret value from your vault: '{str(e)}'.")
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.09GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Base model loaded.
# LoRA adapter loaded.
# Model ready for evaluation.
#
# Test set:
# Rows: 2375
#                              queue priority
# 0  Service Outages and Maintenance     high
# 1                Technical Support   medium
# 2             Billing and Payments   medium
# 3                  Product Support     high
# 4                       IT Support     high
#
# Starting evaluation...
# Total tickets: 2375
# This may take a while on the T4.
#
# Evaluated 100/2375
# Evaluated 200/2375
# Evaluated 300/2375
# Evaluated 400/2375
# Evaluated 500/2375
# Evaluated 600/2375
# Evaluated 700/2375
# Evaluated 800/2375
# Evaluated 900/2375
# Evaluated 1000/2375
# Evaluated 1100/2375
# Evaluated 1200/2375
# Evaluated 1300/2375
# Evaluated 1400/2375
# Evaluated 1500/2375
# Evaluated 1600/2375
# Evaluated 1700/2375
# Evaluated 1800/2375
# Evaluated 1900/2375
# Evaluated 2000/2375
# Evaluated 2100/2375
# Evaluated 2200/2375
# Evaluated 2300/2375
#
# ============================================================
# FINAL QLoRA EVALUATION
# ============================================================
#
# Total tickets:       2375
# Valid predictions:   2375
# Invalid predictions: 0
#
# --- Valid Prediction Metrics ---
# Queue Accuracy:      0.3697
# Queue Macro-F1:      0.1941
# Priority Accuracy:   0.4754
# Priority Macro-F1:   0.3527
# Joint Accuracy:      0.2105
# JSON Validity:       1.0000
#
# --- Strict End-to-End Metrics ---
# Strict Queue Acc:    0.3697
# Strict Priority Acc: 0.4754
# Strict Joint Acc:    0.2105
#
# Saved:
# /content/drive/MyDrive/SupportOpsAI/results/qlora_test_predictions.csv
# /content/drive/MyDrive/SupportOpsAI/results/qlora_metrics.json
#
# ============================================================
# SAMPLE PREDICTIONS
# ============================================================
#
# True:
# {'queue': 'Service Outages and Maintenance', 'priority': 'high'}
# Model:
# {"queue": "Technical Support", "priority": "high"}
#
# True:
# {'queue': 'Technical Support', 'priority': 'medium'}
# Model:
# {"queue": "Technical Support", "priority": "high"}
#
# True:
# {'queue': 'Billing and Payments', 'priority': 'medium'}
# Model:
# {"queue": "Technical Support", "priority": "high"}
#
# True:
# {'queue': 'Product Support', 'priority': 'high'}
# Model:
# {"queue": "Technical Support", "priority": "high"}
#
# True:
# {'queue': 'IT Support', 'priority': 'high'}
# Model:
# {"queue": "Technical Support", "priority": "high"}
#
# True:
# {'queue': 'Technical Support', 'priority': 'high'}
# Model:
# {"queue": "Technical Support", "priority": "high"}
#
# True:
# {'queue': 'Technical Support', 'priority': 'medium'}
# Model:
# {"queue": "Technical Support", "priority": "medium"}
#
# True:
# {'queue': 'Product Support', 'priority': 'medium'}
# Model:
# {"queue": "Technical Support", "priority": "medium"}
#
# True:
# {'queue': 'Technical Support', 'priority': 'medium'}
# Model:
# {"queue": "Technical Support", "priority": "medium"}
#
# True:
# {'queue': 'Technical Support', 'priority': 'high'}
# Model:
# {"queue": "Technical Support", "priority": "high"}

# %%
from sklearn.metrics import (
    classification_report,
    confusion_matrix
)
import pandas as pd
import numpy as np


# ============================================================
# 1. Queue class distribution in TEST SET
# ============================================================

print("=" * 70)
print("TRUE QUEUE DISTRIBUTION")
print("=" * 70)

queue_distribution = (
    test_df["queue"]
    .value_counts()
    .rename_axis("queue")
    .reset_index(name="count")
)

queue_distribution["percentage"] = (
    queue_distribution["count"] / len(test_df) * 100
).round(2)

print(queue_distribution.to_string(index=False))


# ============================================================
# 2. Queue classification report
# ============================================================

valid_df = pred_df[pred_df["valid_json"]].copy()

queue_labels = sorted(test_df["queue"].unique())

print("\n" + "=" * 70)
print("QUEUE CLASSIFICATION REPORT")
print("=" * 70)

queue_report = classification_report(
    valid_df["true_queue"],
    valid_df["predicted_queue"],
    labels=queue_labels,
    output_dict=True,
    zero_division=0
)

queue_report_df = pd.DataFrame(queue_report).T

print(
    queue_report_df[
        ["precision", "recall", "f1-score", "support"]
    ].round(3).to_string()
)


# ============================================================
# 3. Queue confusion matrix
# ============================================================

print("\n" + "=" * 70)
print("QUEUE CONFUSION MATRIX")
print("=" * 70)

queue_cm = confusion_matrix(
    valid_df["true_queue"],
    valid_df["predicted_queue"],
    labels=queue_labels
)

queue_cm_df = pd.DataFrame(
    queue_cm,
    index=queue_labels,
    columns=queue_labels
)

print("\nRows = TRUE")
print("Columns = PREDICTED\n")

print(queue_cm_df.to_string())


# ============================================================
# 4. Most common queue mistakes
# ============================================================

mistakes = valid_df[
    valid_df["true_queue"] != valid_df["predicted_queue"]
].copy()

mistake_pairs = (
    mistakes
    .groupby(["true_queue", "predicted_queue"])
    .size()
    .reset_index(name="count")
    .sort_values("count", ascending=False)
)

print("\n" + "=" * 70)
print("TOP QUEUE CONFUSIONS")
print("=" * 70)

print(
    mistake_pairs.head(20).to_string(index=False)
)


# ============================================================
# 5. What does the model predict?
# ============================================================

print("\n" + "=" * 70)
print("MODEL PREDICTED QUEUE DISTRIBUTION")
print("=" * 70)

pred_queue_distribution = (
    valid_df["predicted_queue"]
    .value_counts()
    .rename_axis("queue")
    .reset_index(name="predicted_count")
)

print(
    pred_queue_distribution.to_string(index=False)
)


# ============================================================
# 6. Priority classification report
# ============================================================

priority_labels = sorted(test_df["priority"].unique())

print("\n" + "=" * 70)
print("PRIORITY CLASSIFICATION REPORT")
print("=" * 70)

priority_report = classification_report(
    valid_df["true_priority"],
    valid_df["predicted_priority"],
    labels=priority_labels,
    output_dict=True,
    zero_division=0
)

priority_report_df = pd.DataFrame(priority_report).T

print(
    priority_report_df[
        ["precision", "recall", "f1-score", "support"]
    ].round(3).to_string()
)


# ============================================================
# 7. Priority confusion matrix
# ============================================================

print("\n" + "=" * 70)
print("PRIORITY CONFUSION MATRIX")
print("=" * 70)

priority_cm = confusion_matrix(
    valid_df["true_priority"],
    valid_df["predicted_priority"],
    labels=priority_labels
)

priority_cm_df = pd.DataFrame(
    priority_cm,
    index=priority_labels,
    columns=priority_labels
)

print("\nRows = TRUE")
print("Columns = PREDICTED\n")

print(priority_cm_df.to_string())
# Out:
# ======================================================================
# TRUE QUEUE DISTRIBUTION
# ======================================================================
#                           queue  count  percentage
#               Technical Support    686       28.88
#                 Product Support    444       18.69
#                Customer Service    357       15.03
#                      IT Support    283       11.92
#            Billing and Payments    242       10.19
#           Returns and Exchanges    117        4.93
# Service Outages and Maintenance     94        3.96
#             Sales and Pre-Sales     72        3.03
#                 Human Resources     46        1.94
#                 General Inquiry     34        1.43
#
# ======================================================================
# QUEUE CLASSIFICATION REPORT
# ======================================================================
#                                  precision  recall  f1-score  support
# Billing and Payments                 0.971   0.545     0.698   242.00
# Customer Service                     0.238   0.042     0.071   357.00
# General Inquiry                      0.000   0.000     0.000    34.00
# Human Resources                      1.000   0.022     0.043    46.00
# IT Support                           0.000   0.000     0.000   283.00
# Product Support                      0.283   0.038     0.067   444.00
# Returns and Exchanges                1.000   0.034     0.066   117.00
# Sales and Pre-Sales                  1.000   0.014     0.027    72.00
# Service Outages and Maintenance      0.861   0.330     0.477    94.00
# Technical Support                    0.326   0.987     0.491   686.00
# accuracy                             0.370   0.370     0.370     0.37
# macro avg                            0.568   0.201     0.194  2375.00
# weighted avg                         0.415   0.370     0.260  2375.00
#
# ======================================================================
# QUEUE CONFUSION MATRIX
# ======================================================================
#
# Rows = TRUE
# Columns = PREDICTED
#
#                                  Billing and Payments  Customer Service  General Inquiry  Human Resources  IT Support  Product Support  Returns and Exchanges  Sales and Pre-Sales  Service Outages and Maintenance  Technical Support
# Billing and Payments                              132                 9                0                0           0                2                      0                    0                                0                 99
# Customer Service                                    0                15                0                0           0               11                      0                    0                                1                330
# General Inquiry                                     0                 2                0                0           0                1                      0                    0                                0                 31
# Human Resources                                     0                 1                0                1           0                6                      0                    0                                0                 38
# IT Support                                          0                 8                0                0           0                3                      0                    0                                0                272
# Product Support                                     0                 8                0                0           0               17                      0                    0                                2                417
# Returns and Exchanges                               2                 8                0                0           0               10                      4                    0                                0                 93
# Sales and Pre-Sales                                 2                 8                0                0           0                6                      0                    1                                0                 55
# Service Outages and Maintenance                     0                 0                0                0           0                1                      0                    0                               31                 62
# Technical Support                                   0                 4                0                0           0                3                      0                    0                                2                677
#
# ======================================================================
# TOP QUEUE CONFUSIONS
# ======================================================================
#                      true_queue   predicted_queue  count
#                 Product Support Technical Support    417
#                Customer Service Technical Support    330
#                      IT Support Technical Support    272
#            Billing and Payments Technical Support     99
#           Returns and Exchanges Technical Support     93
# Service Outages and Maintenance Technical Support     62
#             Sales and Pre-Sales Technical Support     55
#                 Human Resources Technical Support     38
#                 General Inquiry Technical Support     31
#                Customer Service   Product Support     11
#           Returns and Exchanges   Product Support     10
#            Billing and Payments  Customer Service      9
#                      IT Support  Customer Service      8
#             Sales and Pre-Sales  Customer Service      8
#           Returns and Exchanges  Customer Service      8
#                 Product Support  Customer Service      8
#             Sales and Pre-Sales   Product Support      6
#                 Human Resources   Product Support      6
#               Technical Support  Customer Service      4
#               Technical Support   Product Support      3
#
# ======================================================================
# MODEL PREDICTED QUEUE DISTRIBUTION
# ======================================================================
#                           queue  predicted_count
#               Technical Support             2074
#            Billing and Payments              136
#                Customer Service               63
#                 Product Support               60
# Service Outages and Maintenance               36
#           Returns and Exchanges                4
#                 Human Resources                1
#             Sales and Pre-Sales                1
#
# ======================================================================
# PRIORITY CLASSIFICATION REPORT
# ======================================================================
#               precision  recall  f1-score   support
# high              0.478   0.727     0.577   912.000
# low               0.500   0.004     0.008   486.000
# medium            0.471   0.475     0.473   977.000
# accuracy          0.475   0.475     0.475     0.475
# macro avg         0.483   0.402     0.353  2375.000
# weighted avg      0.480   0.475     0.418  2375.000
#
# ======================================================================
# PRIORITY CONFUSION MATRIX
# ======================================================================
#
# Rows = TRUE
# Columns = PREDICTED
#
#         high  low  medium
# high     663    0     249
# low      212    2     272
# medium   511    2     464

# %%
# ============================================================
# FINAL RESULTS — SupportOpsAI
# ============================================================

import os
import json
import pandas as pd

results_dir = "/content/drive/MyDrive/SupportOpsAI/results"
os.makedirs(results_dir, exist_ok=True)

# Final results from the completed evaluation
baseline_results = {
    "model": "Qwen/Qwen2.5-1.5B-Instruct",
    "test_samples": 2375,
    "valid_predictions": 2277,
    "invalid_predictions": 98,
    "queue_accuracy": 0.3166,
    "queue_macro_f1": 0.2040,
    "priority_accuracy": 0.3781,
    "priority_macro_f1": 0.2375,
    "joint_accuracy": 0.1524,
    "json_validity": 0.9587
}

qlora_results = {
    "base_model": "Qwen/Qwen2.5-1.5B-Instruct",
    "method": "QLoRA",
    "test_samples": 2375,
    "valid_predictions": 2375,
    "invalid_predictions": 0,
    "queue_accuracy": 0.3697,
    "queue_macro_f1": 0.1941,
    "priority_accuracy": 0.4754,
    "priority_macro_f1": 0.3527,
    "joint_accuracy": 0.2105,
    "json_validity": 1.0000
}

# Save individual result files
with open(os.path.join(results_dir, "baseline_results.json"), "w") as f:
    json.dump(baseline_results, f, indent=4)

with open(os.path.join(results_dir, "qlora_results.json"), "w") as f:
    json.dump(qlora_results, f, indent=4)


# Comparison table
comparison = pd.DataFrame({
    "Metric": [
        "Queue Accuracy",
        "Queue Macro-F1",
        "Priority Accuracy",
        "Priority Macro-F1",
        "Joint Accuracy",
        "JSON Validity"
    ],
    "Baseline": [
        0.3166,
        0.2040,
        0.3781,
        0.2375,
        0.1524,
        0.9587
    ],
    "QLoRA": [
        0.3697,
        0.1941,
        0.4754,
        0.3527,
        0.2105,
        1.0000
    ]
})

comparison["Change"] = comparison["QLoRA"] - comparison["Baseline"]

comparison.to_csv(
    os.path.join(results_dir, "model_comparison.csv"),
    index=False
)

print("Results saved to:")
print(results_dir)

print("\nFiles:")
print("- baseline_results.json")
print("- qlora_results.json")
print("- model_comparison.csv")
# Out:
# Results saved to:
# /content/drive/MyDrive/SupportOpsAI/results
#
# Files:
# - baseline_results.json
# - qlora_results.json
# - model_comparison.csv

# %% [markdown]
# # Final Evaluation
#
# The fine-tuned Qwen2.5-1.5B-Instruct model was evaluated on the untouched
# 2,375-example test set and compared against the base model.
#
# | Metric | Baseline | QLoRA |
# |---|---:|---:|
# | Queue Accuracy | 31.66% | **36.97%** |
# | Queue Macro-F1 | **20.40%** | 19.41% |
# | Priority Accuracy | 37.81% | **47.54%** |
# | Priority Macro-F1 | 23.75% | **35.27%** |
# | Joint Accuracy | 15.24% | **21.05%** |
# | JSON Validity | 95.87% | **100.00%** |
#
# ## Key Findings
#
# - QLoRA improved queue accuracy from 31.66% to 36.97%.
# - Priority accuracy improved from 37.81% to 47.54%.
# - Priority Macro-F1 improved from 23.75% to 35.27%.
# - Joint accuracy improved from 15.24% to 21.05%.
# - JSON validity reached 100% after using sufficient generation length.
# - Queue classification remained challenging, with the model showing a strong
#   bias toward the Technical Support class.

# %%
# ============================================================
# SAVE SUPPORTOPSAI EVALUATION ARTIFACTS TO GOOGLE DRIVE
# ============================================================

import os
import json

results_dir = "/content/drive/MyDrive/SupportOpsAI/results"
os.makedirs(results_dir, exist_ok=True)

# ------------------------------------------------------------
# 1. Save full prediction dataframe
# ------------------------------------------------------------

predictions_path = os.path.join(
    results_dir,
    "qlora_test_predictions.csv"
)

pred_df.to_csv(predictions_path, index=False)


# ------------------------------------------------------------
# 2. Save queue distribution
# ------------------------------------------------------------

queue_distribution.to_csv(
    os.path.join(results_dir, "test_queue_distribution.csv"),
    index=False
)


# ------------------------------------------------------------
# 3. Save queue classification report
# ------------------------------------------------------------

queue_report_df.to_csv(
    os.path.join(results_dir, "queue_classification_report.csv")
)


# ------------------------------------------------------------
# 4. Save queue confusion matrix
# ------------------------------------------------------------

queue_cm_df.to_csv(
    os.path.join(results_dir, "queue_confusion_matrix.csv")
)


# ------------------------------------------------------------
# 5. Save top queue mistakes
# ------------------------------------------------------------

mistake_pairs.to_csv(
    os.path.join(results_dir, "queue_mistake_pairs.csv"),
    index=False
)


# ------------------------------------------------------------
# 6. Save predicted queue distribution
# ------------------------------------------------------------

pred_queue_distribution.to_csv(
    os.path.join(results_dir, "predicted_queue_distribution.csv"),
    index=False
)


# ------------------------------------------------------------
# 7. Save priority classification report
# ------------------------------------------------------------

priority_report_df.to_csv(
    os.path.join(results_dir, "priority_classification_report.csv")
)


# ------------------------------------------------------------
# 8. Save priority confusion matrix
# ------------------------------------------------------------

priority_cm_df.to_csv(
    os.path.join(results_dir, "priority_confusion_matrix.csv")
)


# ------------------------------------------------------------
# 9. Save final headline metrics
# ------------------------------------------------------------

final_metrics = {
    "test_samples": 2375,
    "valid_predictions": 2375,
    "invalid_predictions": 0,

    "queue_accuracy": 0.3697,
    "queue_macro_f1": 0.1941,

    "priority_accuracy": 0.4754,
    "priority_macro_f1": 0.3527,

    "joint_accuracy": 0.2105,

    "json_validity": 1.0000
}

with open(
    os.path.join(results_dir, "qlora_final_metrics.json"),
    "w"
) as f:
    json.dump(final_metrics, f, indent=4)


# ------------------------------------------------------------
# 10. Save baseline vs QLoRA comparison
# ------------------------------------------------------------

comparison_df = pd.DataFrame({
    "Metric": [
        "Queue Accuracy",
        "Queue Macro-F1",
        "Priority Accuracy",
        "Priority Macro-F1",
        "Joint Accuracy",
        "JSON Validity"
    ],

    "Baseline": [
        0.3166,
        0.2040,
        0.3781,
        0.2375,
        0.1524,
        0.9587
    ],

    "QLoRA": [
        0.3697,
        0.1941,
        0.4754,
        0.3527,
        0.2105,
        1.0000
    ]
})

comparison_df["Absolute Change"] = (
    comparison_df["QLoRA"] -
    comparison_df["Baseline"]
)

comparison_df.to_csv(
    os.path.join(results_dir, "baseline_vs_qlora.csv"),
    index=False
)


# ------------------------------------------------------------
# 11. Save a human-readable summary
# ------------------------------------------------------------

summary = """SupportOpsAI — Final QLoRA Evaluation
=======================================

Model:
Qwen/Qwen2.5-1.5B-Instruct

Method:
4-bit QLoRA

Test set:
2,375 untouched test examples

Results:
Queue Accuracy:       36.97%
Queue Macro-F1:       19.41%
Priority Accuracy:    47.54%
Priority Macro-F1:    35.27%
Joint Accuracy:       21.05%
JSON Validity:       100.00%

Baseline → QLoRA:
Queue Accuracy:       31.66% → 36.97%
Queue Macro-F1:       20.40% → 19.41%
Priority Accuracy:    37.81% → 47.54%
Priority Macro-F1:    23.75% → 35.27%
Joint Accuracy:       15.24% → 21.05%
JSON Validity:        95.87% → 100.00%

Main observation:
The QLoRA model substantially improved priority classification and
joint accuracy. Queue classification remained challenging, with
a strong prediction bias toward the Technical Support class.
"""

with open(
    os.path.join(results_dir, "README_results.txt"),
    "w"
) as f:
    f.write(summary)


# ------------------------------------------------------------
# DONE
# ------------------------------------------------------------

print("=" * 60)
print("EVALUATION ARTIFACTS SAVED")
print("=" * 60)
print(f"\nLocation:\n{results_dir}\n")

for filename in sorted(os.listdir(results_dir)):
    print("✓", filename)
# Out:
# ============================================================
# EVALUATION ARTIFACTS SAVED
# ============================================================
#
# Location:
# /content/drive/MyDrive/SupportOpsAI/results
#
# ✓ README_results.txt
# ✓ baseline_results.json
# ✓ baseline_vs_qlora.csv
# ✓ model_comparison.csv
# ✓ predicted_queue_distribution.csv
# ✓ priority_classification_report.csv
# ✓ priority_confusion_matrix.csv
# ✓ qlora_final_metrics.json
# ✓ qlora_metrics.json
# ✓ qlora_results.json
# ✓ qlora_test_predictions.csv
# ✓ queue_classification_report.csv
# ✓ queue_confusion_matrix.csv
# ✓ queue_mistake_pairs.csv
# ✓ test_queue_distribution.csv
